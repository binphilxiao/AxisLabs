# %%
# !pip install yfinance
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import tensorflow as tf
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.6/dist-packages (0.1.55)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.6/dist-packages (from yfinance) (4.6.2)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from yfinance) (0.0.9)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.6/dist-packages (from yfinance) (1.1.5)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.6/dist-packages (from yfinance) (2.23.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.6/dist-packages (from yfinance) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24->yfinance) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)

# %%
# Download stock data and plot the history diagram

import yfinance as yf
from datetime import datetime

stockName = "GOOGL"
stkTicker = yf.Ticker(stockName)
dfHist = stkTicker.history(start="2005-01-01", end=datetime.today().strftime('%Y-%m-%d'), interval = "1d")
dataHist = dfHist[['Open','High','Low','Close','Volume']].to_numpy()
np.set_printoptions(threshold=np.inf)
plt.style.use("default")
plt.xlabel("Date")
plt.ylabel("Price")
plt.plot(dataHist[:,3])

# %%
# Preprocess the historical data
# Format data array to LSTM
# -----------------------------------------------------------------------------------
#|  0-4044(4045)    dataClose, dataOpen, dataHist                                    |
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
#|  1-4044(4044)    dataClose   dataset                                              |
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
#|         datasetTrain                           |   datasetTest                    |
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
#|         0-2446  xTrain             | 2447-2546 |                                  |
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
#|       0-99     |     100-2546     yTrain      |                                  |
# -----------------------------------------------------------------------------------

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# ------------------x = Close--------------------
dataset = np.array(dataHist)
dataset = dataset.reshape(-1,5)

# ------------------With scaler--------------------
minmaxScaler = MinMaxScaler(feature_range=(0, 1), copy=True)
_dataset = minmaxScaler.fit_transform(dataset)
print("The max =", minmaxScaler.data_max_,", the Min =",minmaxScaler.data_min_)
# Out:
# The max = [2.10000000e+03 2.11500000e+03 2.06335010e+03 2.08883008e+03
#  8.21511670e+07] , the Min = [8.77377396e+01 8.92892914e+01 8.63713684e+01 8.75825806e+01
#  4.65600000e+05]

# %%
# Get train set and test set

from sklearn.model_selection import train_test_split

sizeTrain = int(_dataset.shape[0]*0.63)
sizeTest = _dataset.shape[0] - sizeTrain
print("The length of data is:",_dataset.shape[0], \
      "\nThe length of Training is:", sizeTrain, \
      "\nThe length of Testing is:", sizeTest)
_Train = _dataset[ : sizeTrain, : ]
_Test = _dataset[sizeTrain : , : ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-98131ace35d4> in <module>()
#       3 from sklearn.model_selection import train_test_split
#       4
# ----> 5 sizeTrain = int(_dataset.shape[0]*0.63)
#       6 sizeTest = _dataset.shape[0] - sizeTrain
#       7 print("The length of data is:",_dataset.shape[0],       "\nThe length of Training is:", sizeTrain,       "\nThe length of Testing is:", sizeTest)
#
# NameError: name '_dataset' is not defined

# %%
# Format data array to LSTM
# -----------------------------------------------------------------------------------
#|  0-4044(4045)    dataClose, dataOpen, dataHist                                    |
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
#|  0  |   1-4044(4044)                                                              |
# -----------------------------------------------------------------------------------
#      ------------------------------------------------------------------------------
#     |    datasetTrain                           |   datasetTest                    |
#      ------------------------------------------------------------------------------
#      ------------------------------------------------------------------------------
#     |    0-2446  xTrain             | 2447-2546 |                                  |
#      ------------------------------------------------------------------------------
#      ------------------------------------------------------------------------------
#     |   0-99     |     100-2546     yTrain      |                                  |
#      ------------------------------------------------------------------------------

DIM_LSTM = 100

def catalogYData(y):
  out = []
  for i in range(y.size):
    if i == 0:
      out.append(1)
    elif y[i] >= y[i-1]:
      out.append(1)
    else:
      out.append(0)
  out = np.array(out)
  out = out.reshape(-1,1)
  return out

def formatData(dataSet,dimLSTM):
    X,Y = [],[]
    for i in range(dataSet.shape[0] - dimLSTM):
        X.append(dataSet[i : i+dimLSTM, : ])
        Y.append(dataSet[i + dimLSTM, : ])
    X = np.array(X)
    Y = np.array(Y)
    #X = X.reshape(-1,dimLSTM)
    #Y = Y.reshape(-1,5)
    X = X.reshape(X.shape[0], X.shape[1],5)
    return X,Y

_xTrain, _yTrain = formatData(_Train, DIM_LSTM)
_xTest, _yTest = formatData(_Test, DIM_LSTM)
_yTrain = _yTrain[:,3].reshape(-1,1)
_yTest = _yTest[:,3].reshape(-1,1)
_yTrain = catalogYData(_yTrain)
_yTest = catalogYData(_yTest)
xTrain, yTrain = formatData(dataset[ : sizeTrain, : ], DIM_LSTM)
xTest, yTest = formatData(dataset[sizeTrain : , : ], DIM_LSTM)
yTrain = yTrain[:,3].reshape(-1,1)
yTest = yTest[:,3].reshape(-1,1)

# %%
# Build the model

import keras 
from keras.models import Sequential
from keras.models import Model
from keras.layers import Dense, Dropout, LSTM, GRU, Input, Activation, concatenate
from keras.callbacks import TensorBoard
from keras import optimizers

UNIT_LSTM = 50

def model_1():
  model = keras.Sequential()
  model.add(LSTM(UNIT_LSTM, return_sequences = True, input_shape=(DIM_LSTM,5)))
  model.add(LSTM(UNIT_LSTM, return_sequences = True))
  model.add(LSTM(UNIT_LSTM))
  model.add(Dense(1))
  model.compile(loss='mean_squared_error', optimizer = 'adam')
  return model

def model_2():
  lstm_input = Input(shape=(DIM_LSTM, 5), name='lstm_input')
  x = LSTM(50, name='lstm_0')(lstm_input)
  x = Dropout(0.2, name='lstm_dropout_0')(x)
  x = Dense(64, name='dense_0')(x)
  x = Activation('sigmoid', name='sigmoid_0')(x)
  x = Dense(1, name='dense_1')(x)
  output = Activation('linear', name='linear_output')(x)
  model = Model(inputs=lstm_input, outputs=output)
  adam = optimizers.Adam(lr=0.0005)
  model.compile(optimizer=adam, loss='mse')
  return model

def model_3():
  input = Input(shape=(DIM_LSTM, 5), name='input')
  x = GRU(UNIT_LSTM, name='lstm_0', return_sequences = True, return_state=True)(input)
  x = GRU(UNIT_LSTM, name='lstm_1', return_sequences = True, return_state=True)(x)
  x = GRU(UNIT_LSTM, name='lstm_2')(x)
  output = Dense(1, activation = 'sigmoid', name='dense_1')(x)
  model = Model(inputs=input, outputs=output, name = 'model_3')
  model.compile(optimizer='sgd', loss='binary_crossentropy')
  return model

model = model_3()
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 100, 5)]     0
# __________________________________________________________________________________________________
# lstm_0 (GRU)                    [(None, 100, 50), (N 8550        input[0][0]
# __________________________________________________________________________________________________
# lstm_1 (GRU)                    [(None, 100, 50), (N 15300       lstm_0[0][0]
#                                                                  lstm_0[0][1]
# __________________________________________________________________________________________________
# lstm_2 (GRU)                    (None, 50)           15300       lstm_1[0][0]
#                                                                  lstm_1[0][1]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            51          lstm_2[0][0]
# ==================================================================================================
# Total params: 39,201
# Trainable params: 39,201
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Fit the model   
model.fit(x=_xTrain,y=_yTrain, epochs=10, batch_size=32, shuffle = True, validation_split = 0.1, callbacks=[TensorBoard(log_dir='./logs', histogram_freq=1)])

# See the training result: type 'tensorboard --logdir=./logs' in terminal
# Out:
# Epoch 1/10
# 69/69 [==============================] - 14s 148ms/step - loss: 0.6935 - val_loss: 0.6936
# Epoch 2/10
# 69/69 [==============================] - 9s 132ms/step - loss: 0.6930 - val_loss: 0.6937
# Epoch 3/10
# 69/69 [==============================] - 9s 132ms/step - loss: 0.6940 - val_loss: 0.6939
# Epoch 4/10
# 69/69 [==============================] - 9s 132ms/step - loss: 0.6938 - val_loss: 0.6940
# Epoch 5/10
# 69/69 [==============================] - 9s 131ms/step - loss: 0.6942 - val_loss: 0.6940
# Epoch 6/10
# 69/69 [==============================] - 9s 131ms/step - loss: 0.6934 - val_loss: 0.6938
# Epoch 7/10
# 69/69 [==============================] - 9s 133ms/step - loss: 0.6939 - val_loss: 0.6939
# Epoch 8/10
# 69/69 [==============================] - 9s 134ms/step - loss: 0.6936 - val_loss: 0.6939
# Epoch 9/10
# 69/69 [==============================] - 9s 135ms/step - loss: 0.6935 - val_loss: 0.6937
# Epoch 10/10
# 69/69 [==============================] - 9s 133ms/step - loss: 0.6933 - val_loss: 0.6939

# %%
# Make predictions

from sklearn.metrics import mean_squared_error

_predTrain = model.predict(_xTrain)
_predTest= model.predict(_xTest)
#_predTrain = np.c_[_predTrain,_predTrain,_predTrain,_predTrain,_predTrain]
#_predTest = np.c_[_predTest,_predTest,_predTest,_predTest,_predTest]
#predTrain = minmaxScaler.inverse_transform(_predTrain)
#predTest = minmaxScaler.inverse_transform(_predTest)
predTrain = _predTrain * 700
predTest = _predTest * 700
#predTrain = predTrain[:,3]
#predTest = predTest[:,3]
#mean_squared_error(predTrain,yTrain)

# %%
plt.figure(figsize=(20, 6))
plt.grid(ls='--')
plt.plot(predTest[0:200], color='green', label='prediction')
plt.plot(yTest[0:200], color='red', label='Real')
plt.legend()

# %%
def SumRes(pred,close,lever,isPrint):
    pred = pred.flatten()
    j = 0
    for i in range(pred.size):
        if i == 0:
            gain = 1
        else:
            if predTrain[i] > 0:
                j=j+1
                gain = gain * (close[i-1] + lever * (close[i]-close[i-1])) / close[i-1]
                if isPrint !=0:
                    print(i, "\tCurrClose:%.02f" %close[i], \
                             "  \tPredCurrGain%+.07f" %pred[i], \
                             "  \tActualGain%+.02f" %(close[i]/close[i-1]), \
                             "  \tPredLongTermGain%+.02f" %gain)
    if isPrint !=0:
        print("\n\n\nFinal gain comparasion:\t",gain,"rather than Long-Term-Gain",close[pred.size-1]/close[0],", Trading times",j)
    return gain

# %%
def dispLever(pred,close,):
    disp  = []
    lever = []
    l = float(0)
    while l<=10:
        disp.append(SumRes(pred,close,l,0))
        lever.append(l)
        l=l+0.1
    disp = np.array(disp).reshape(-1,1)
    lever = np.array(lever).reshape(-1,1)
    plt.figure(figsize=(10, 6))
    plt.xticks(np.linspace(0, 10, 21))
    plt.grid(ls='--')
    plt.plot(lever, disp)

# %%
dispLever(predTrain,yTrain)

# %%
dispLever(predTest,yTest)

# %%
SumRes(predTrain,yTrain,2.25,1)
# Out:
# 1 	CurrClose:133.13   	PredCurrGain+128.8464050   	ActualGain+1.03   	PredLongTermGain+1.06
# 2 	CurrClose:138.77   	PredCurrGain+128.9804535   	ActualGain+1.04   	PredLongTermGain+1.16
# 3 	CurrClose:144.14   	PredCurrGain+133.2959290   	ActualGain+1.04   	PredLongTermGain+1.26
# 4 	CurrClose:144.09   	PredCurrGain+141.1852264   	ActualGain+1.00   	PredLongTermGain+1.26
# 5 	CurrClose:140.27   	PredCurrGain+142.7373810   	ActualGain+0.97   	PredLongTermGain+1.18
# 6 	CurrClose:145.62   	PredCurrGain+141.3004913   	ActualGain+1.04   	PredLongTermGain+1.29
# 7 	CurrClose:146.71   	PredCurrGain+141.9052887   	ActualGain+1.01   	PredLongTermGain+1.31
# 8 	CurrClose:139.92   	PredCurrGain+144.2430267   	ActualGain+0.95   	PredLongTermGain+1.17
# 9 	CurrClose:143.30   	PredCurrGain+142.9758759   	ActualGain+1.02   	PredLongTermGain+1.24
# 10 	CurrClose:141.39   	PredCurrGain+140.9740295   	ActualGain+0.99   	PredLongTermGain+1.20
# 11 	CurrClose:141.52   	PredCurrGain+138.9176178   	ActualGain+1.00   	PredLongTermGain+1.20
# 12 	CurrClose:139.31   	PredCurrGain+137.3666229   	ActualGain+0.98   	PredLongTermGain+1.16
# 13 	CurrClose:137.54   	PredCurrGain+136.1664886   	ActualGain+0.99   	PredLongTermGain+1.13
# 14 	CurrClose:138.86   	PredCurrGain+135.7595520   	ActualGain+1.01   	PredLongTermGain+1.15
# 15 	CurrClose:140.29   	PredCurrGain+135.3247681   	ActualGain+1.01   	PredLongTermGain+1.18
# 16 	CurrClose:143.49   	PredCurrGain+135.6447754   	ActualGain+1.02   	PredLongTermGain+1.24
# 17 	CurrClose:144.06   	PredCurrGain+137.9055481   	ActualGain+1.00   	PredLongTermGain+1.25
# 18 	CurrClose:144.79   	PredCurrGain+140.1762085   	ActualGain+1.01   	PredLongTermGain+1.26
# 19 	CurrClose:145.00   	PredCurrGain+141.3166504   	ActualGain+1.00   	PredLongTermGain+1.27
# 20 	CurrClose:148.77   	PredCurrGain+142.2673950   	ActualGain+1.03   	PredLongTermGain+1.34
# 21 	CurrClose:152.20   	PredCurrGain+144.4148560   	ActualGain+1.02   	PredLongTermGain+1.41
# 22 	CurrClose:151.15   	PredCurrGain+147.1167908   	ActualGain+0.99   	PredLongTermGain+1.39
# 23 	CurrClose:146.51   	PredCurrGain+149.4953308   	ActualGain+0.97   	PredLongTermGain+1.29
# 24 	CurrClose:147.22   	PredCurrGain+148.4869385   	ActualGain+1.00   	PredLongTermGain+1.31
# 25 	CurrClose:145.77   	PredCurrGain+146.5543365   	ActualGain+0.99   	PredLongTermGain+1.28
# 26 	CurrClose:148.00   	PredCurrGain+144.2787628   	ActualGain+1.02   	PredLongTermGain+1.32
# 27 	CurrClose:145.91   	PredCurrGain+143.3623047   	ActualGain+0.99   	PredLongTermGain+1.28
# 28 	CurrClose:147.92   	PredCurrGain+143.4666748   	ActualGain+1.01   	PredLongTermGain+1.32
# 29 	CurrClose:148.26   	PredCurrGain+143.9228210   	ActualGain+1.00   	PredLongTermGain+1.33
# 30 	CurrClose:146.82   	PredCurrGain+144.8992767   	ActualGain+0.99   	PredLongTermGain+1.30
# 31 	CurrClose:146.04   	PredCurrGain+145.1959839   	ActualGain+0.99   	PredLongTermGain+1.28
# 32 	CurrClose:149.58   	PredCurrGain+144.7508240   	ActualGain+1.02   	PredLongTermGain+1.35
# 33 	CurrClose:150.60   	PredCurrGain+146.0052032   	ActualGain+1.01   	PredLongTermGain+1.37
# 34 	CurrClose:150.75   	PredCurrGain+148.3304596   	ActualGain+1.00   	PredLongTermGain+1.38
# 35 	CurrClose:149.92   	PredCurrGain+148.9626923   	ActualGain+0.99   	PredLongTermGain+1.36
# 36 	CurrClose:155.11   	PredCurrGain+148.5568085   	ActualGain+1.03   	PredLongTermGain+1.46
# 37 	CurrClose:156.16   	PredCurrGain+150.6786652   	ActualGain+1.01   	PredLongTermGain+1.49
# 38 	CurrClose:157.13   	PredCurrGain+152.4687958   	ActualGain+1.01   	PredLongTermGain+1.51
# 39 	CurrClose:151.35   	PredCurrGain+155.3267975   	ActualGain+0.96   	PredLongTermGain+1.38
# 40 	CurrClose:148.07   	PredCurrGain+154.0591736   	ActualGain+0.98   	PredLongTermGain+1.31
# 41 	CurrClose:148.19   	PredCurrGain+150.0880585   	ActualGain+1.00   	PredLongTermGain+1.32
# 42 	CurrClose:148.61   	PredCurrGain+146.7081146   	ActualGain+1.00   	PredLongTermGain+1.33
# 43 	CurrClose:146.90   	PredCurrGain+145.1794128   	ActualGain+0.99   	PredLongTermGain+1.29
# 44 	CurrClose:144.02   	PredCurrGain+144.4821930   	ActualGain+0.98   	PredLongTermGain+1.23
# 45 	CurrClose:145.95   	PredCurrGain+143.4551697   	ActualGain+1.01   	PredLongTermGain+1.27
# 46 	CurrClose:149.74   	PredCurrGain+143.1157990   	ActualGain+1.03   	PredLongTermGain+1.35
# 47 	CurrClose:148.80   	PredCurrGain+144.7648468   	ActualGain+0.99   	PredLongTermGain+1.33
# 48 	CurrClose:149.01   	PredCurrGain+146.2438354   	ActualGain+1.00   	PredLongTermGain+1.33
# 49 	CurrClose:146.32   	PredCurrGain+146.9455566   	ActualGain+0.98   	PredLongTermGain+1.28
# 50 	CurrClose:145.77   	PredCurrGain+146.7249908   	ActualGain+1.00   	PredLongTermGain+1.27
# 51 	CurrClose:145.93   	PredCurrGain+145.8834839   	ActualGain+1.00   	PredLongTermGain+1.27
# 52 	CurrClose:142.98   	PredCurrGain+145.1497040   	ActualGain+0.98   	PredLongTermGain+1.21
# 53 	CurrClose:142.17   	PredCurrGain+144.0034180   	ActualGain+0.99   	PredLongTermGain+1.20
# 54 	CurrClose:145.01   	PredCurrGain+142.3719177   	ActualGain+1.02   	PredLongTermGain+1.25
# 55 	CurrClose:142.14   	PredCurrGain+141.9397888   	ActualGain+0.98   	PredLongTermGain+1.19
# 56 	CurrClose:142.97   	PredCurrGain+142.0746002   	ActualGain+1.01   	PredLongTermGain+1.21
# 57 	CurrClose:142.69   	PredCurrGain+141.7425537   	ActualGain+1.00   	PredLongTermGain+1.20
# 58 	CurrClose:140.14   	PredCurrGain+141.2461853   	ActualGain+0.98   	PredLongTermGain+1.16
# 59 	CurrClose:140.14   	PredCurrGain+140.0939331   	ActualGain+1.00   	PredLongTermGain+1.16
# 60 	CurrClose:137.14   	PredCurrGain+139.2064056   	ActualGain+0.98   	PredLongTermGain+1.10
# 61 	CurrClose:139.93   	PredCurrGain+138.0048523   	ActualGain+1.02   	PredLongTermGain+1.15
# 62 	CurrClose:141.43   	PredCurrGain+137.5415955   	ActualGain+1.01   	PredLongTermGain+1.18
# 63 	CurrClose:141.44   	PredCurrGain+138.4909668   	ActualGain+1.00   	PredLongTermGain+1.18
# 64 	CurrClose:141.93   	PredCurrGain+139.1316681   	ActualGain+1.00   	PredLongTermGain+1.19
# 65 	CurrClose:144.37   	PredCurrGain+139.9393921   	ActualGain+1.02   	PredLongTermGain+1.23
# 66 	CurrClose:143.78   	PredCurrGain+141.3038177   	ActualGain+1.00   	PredLongTermGain+1.22
# 67 	CurrClose:143.14   	PredCurrGain+142.3724518   	ActualGain+1.00   	PredLongTermGain+1.21
# 68 	CurrClose:143.27   	PredCurrGain+142.7321930   	ActualGain+1.00   	PredLongTermGain+1.21
# 69 	CurrClose:144.37   	PredCurrGain+142.5075989   	ActualGain+1.01   	PredLongTermGain+1.23
# 70 	CurrClose:143.70   	PredCurrGain+142.8845673   	ActualGain+1.00   	PredLongTermGain+1.22
# 71 	CurrClose:147.58   	PredCurrGain+143.1982574   	ActualGain+1.03   	PredLongTermGain+1.30
# 72 	CurrClose:147.84   	PredCurrGain+144.4126587   	ActualGain+1.00   	PredLongTermGain+1.30
# 73 	CurrClose:149.69   	PredCurrGain+146.0746002   	ActualGain+1.01   	PredLongTermGain+1.34
# 74 	CurrClose:155.03   	PredCurrGain+147.3445892   	ActualGain+1.04   	PredLongTermGain+1.44
# 75 	CurrClose:156.00   	PredCurrGain+150.7230682   	ActualGain+1.01   	PredLongTermGain+1.46
# 76 	CurrClose:151.65   	PredCurrGain+153.4981995   	ActualGain+0.97   	PredLongTermGain+1.37
# 77 	CurrClose:151.46   	PredCurrGain+153.5226898   	ActualGain+1.00   	PredLongTermGain+1.37
# 78 	CurrClose:150.25   	PredCurrGain+152.4987640   	ActualGain+0.99   	PredLongTermGain+1.34
# 79 	CurrClose:152.05   	PredCurrGain+150.6923523   	ActualGain+1.01   	PredLongTermGain+1.38
# 80 	CurrClose:154.11   	PredCurrGain+149.7138519   	ActualGain+1.01   	PredLongTermGain+1.42
# 81 	CurrClose:156.11   	PredCurrGain+150.9606934   	ActualGain+1.01   	PredLongTermGain+1.46
# 82 	CurrClose:155.84   	PredCurrGain+152.6380768   	ActualGain+1.00   	PredLongTermGain+1.46
# 83 	CurrClose:157.84   	PredCurrGain+154.5782623   	ActualGain+1.01   	PredLongTermGain+1.50
# 84 	CurrClose:157.30   	PredCurrGain+155.5436554   	ActualGain+1.00   	PredLongTermGain+1.49
# 85 	CurrClose:157.13   	PredCurrGain+156.4956207   	ActualGain+1.00   	PredLongTermGain+1.49
# 86 	CurrClose:153.15   	PredCurrGain+156.3344727   	ActualGain+0.97   	PredLongTermGain+1.40
# 87 	CurrClose:154.96   	PredCurrGain+154.8598938   	ActualGain+1.01   	PredLongTermGain+1.44
# 88 	CurrClose:158.39   	PredCurrGain+153.5220032   	ActualGain+1.02   	PredLongTermGain+1.51
# 89 	CurrClose:159.50   	PredCurrGain+154.9170532   	ActualGain+1.01   	PredLongTermGain+1.53
# 90 	CurrClose:155.66   	PredCurrGain+156.1722412   	ActualGain+0.98   	PredLongTermGain+1.45
# 91 	CurrClose:155.51   	PredCurrGain+156.4041595   	ActualGain+1.00   	PredLongTermGain+1.45
# 92 	CurrClose:156.53   	PredCurrGain+155.4421082   	ActualGain+1.01   	PredLongTermGain+1.47
# 93 	CurrClose:156.65   	PredCurrGain+155.1187897   	ActualGain+1.00   	PredLongTermGain+1.47
# 94 	CurrClose:155.48   	PredCurrGain+155.0567322   	ActualGain+0.99   	PredLongTermGain+1.45
# 95 	CurrClose:153.20   	PredCurrGain+154.5621033   	ActualGain+0.99   	PredLongTermGain+1.40
# 96 	CurrClose:150.64   	PredCurrGain+153.7205505   	ActualGain+0.98   	PredLongTermGain+1.35
# 97 	CurrClose:148.87   	PredCurrGain+151.9036560   	ActualGain+0.99   	PredLongTermGain+1.31
# 98 	CurrClose:148.22   	PredCurrGain+149.6173859   	ActualGain+1.00   	PredLongTermGain+1.30
# 99 	CurrClose:152.65   	PredCurrGain+147.8795166   	ActualGain+1.03   	PredLongTermGain+1.38
# 100 	CurrClose:151.79   	PredCurrGain+147.9896088   	ActualGain+0.99   	PredLongTermGain+1.37
# 101 	CurrClose:154.50   	PredCurrGain+149.1939545   	ActualGain+1.02   	PredLongTermGain+1.42
# 102 	CurrClose:151.75   	PredCurrGain+150.7493134   	ActualGain+0.98   	PredLongTermGain+1.37
# 103 	CurrClose:170.12   	PredCurrGain+152.1404572   	ActualGain+1.12   	PredLongTermGain+1.74
# 104 	CurrClose:174.50   	PredCurrGain+163.0138245   	ActualGain+1.03   	PredLongTermGain+1.84
# 105 	CurrClose:173.63   	PredCurrGain+168.6661072   	ActualGain+1.00   	PredLongTermGain+1.82
# 106 	CurrClose:177.90   	PredCurrGain+170.9099274   	ActualGain+1.02   	PredLongTermGain+1.92
# 107 	CurrClose:176.71   	PredCurrGain+173.3812714   	ActualGain+0.99   	PredLongTermGain+1.89
# 108 	CurrClose:179.26   	PredCurrGain+174.9814606   	ActualGain+1.01   	PredLongTermGain+1.95
# 109 	CurrClose:186.26   	PredCurrGain+176.4965057   	ActualGain+1.04   	PredLongTermGain+2.12
# 110 	CurrClose:189.88   	PredCurrGain+180.5097504   	ActualGain+1.02   	PredLongTermGain+2.21
# 111 	CurrClose:190.03   	PredCurrGain+184.9643097   	ActualGain+1.00   	PredLongTermGain+2.22
# 112 	CurrClose:193.17   	PredCurrGain+187.5854492   	ActualGain+1.02   	PredLongTermGain+2.30
# 113 	CurrClose:195.41   	PredCurrGain+189.3493500   	ActualGain+1.01   	PredLongTermGain+2.36
# 114 	CurrClose:197.71   	PredCurrGain+191.5405273   	ActualGain+1.01   	PredLongTermGain+2.42
# 115 	CurrClose:195.15   	PredCurrGain+194.1362610   	ActualGain+0.99   	PredLongTermGain+2.35
# 116 	CurrClose:189.76   	PredCurrGain+194.5002899   	ActualGain+0.97   	PredLongTermGain+2.21
# 117 	CurrClose:195.75   	PredCurrGain+192.1451263   	ActualGain+1.03   	PredLongTermGain+2.36
# 118 	CurrClose:195.40   	PredCurrGain+191.2811584   	ActualGain+1.00   	PredLongTermGain+2.35
# 119 	CurrClose:198.68   	PredCurrGain+192.5526581   	ActualGain+1.02   	PredLongTermGain+2.44
# 120 	CurrClose:196.60   	PredCurrGain+194.2180328   	ActualGain+0.99   	PredLongTermGain+2.38
# 121 	CurrClose:199.27   	PredCurrGain+194.9322815   	ActualGain+1.01   	PredLongTermGain+2.46
# 122 	CurrClose:201.93   	PredCurrGain+196.1622467   	ActualGain+1.01   	PredLongTermGain+2.53
# 123 	CurrClose:200.31   	PredCurrGain+198.2053528   	ActualGain+0.99   	PredLongTermGain+2.49
# 124 	CurrClose:204.88   	PredCurrGain+199.0129700   	ActualGain+1.02   	PredLongTermGain+2.61
# 125 	CurrClose:208.44   	PredCurrGain+200.0024567   	ActualGain+1.02   	PredLongTermGain+2.72
# 126 	CurrClose:211.64   	PredCurrGain+202.7768707   	ActualGain+1.02   	PredLongTermGain+2.81
# 127 	CurrClose:214.52   	PredCurrGain+206.3266602   	ActualGain+1.01   	PredLongTermGain+2.90
# 128 	CurrClose:211.95   	PredCurrGain+209.7832947   	ActualGain+0.99   	PredLongTermGain+2.82
# 129 	CurrClose:201.97   	PredCurrGain+211.5490265   	ActualGain+0.95   	PredLongTermGain+2.52
# 130 	CurrClose:202.66   	PredCurrGain+208.9951630   	ActualGain+1.00   	PredLongTermGain+2.54
# 131 	CurrClose:207.25   	PredCurrGain+204.3020325   	ActualGain+1.02   	PredLongTermGain+2.67
# 132 	CurrClose:209.06   	PredCurrGain+203.2272034   	ActualGain+1.01   	PredLongTermGain+2.72
# 133 	CurrClose:203.13   	PredCurrGain+204.0281372   	ActualGain+0.97   	PredLongTermGain+2.55
# 134 	CurrClose:202.47   	PredCurrGain+203.2191772   	ActualGain+1.00   	PredLongTermGain+2.53
# 135 	CurrClose:202.31   	PredCurrGain+202.4901733   	ActualGain+1.00   	PredLongTermGain+2.52
# 136 	CurrClose:205.53   	PredCurrGain+201.0717773   	ActualGain+1.02   	PredLongTermGain+2.61
# 137 	CurrClose:204.80   	PredCurrGain+201.0735626   	ActualGain+1.00   	PredLongTermGain+2.59
# 138 	CurrClose:206.51   	PredCurrGain+202.2337799   	ActualGain+1.01   	PredLongTermGain+2.64
# 139 	CurrClose:208.95   	PredCurrGain+203.4721222   	ActualGain+1.01   	PredLongTermGain+2.71
# 140 	CurrClose:209.69   	PredCurrGain+204.9629517   	ActualGain+1.00   	PredLongTermGain+2.73
# 141 	CurrClose:211.49   	PredCurrGain+206.4728546   	ActualGain+1.01   	PredLongTermGain+2.79
# 142 	CurrClose:215.29   	PredCurrGain+207.9482117   	ActualGain+1.02   	PredLongTermGain+2.90
# 143 	CurrClose:212.51   	PredCurrGain+211.1488037   	ActualGain+0.99   	PredLongTermGain+2.81
# 144 	CurrClose:215.09   	PredCurrGain+213.3901062   	ActualGain+1.01   	PredLongTermGain+2.89
# 145 	CurrClose:213.38   	PredCurrGain+213.2409668   	ActualGain+0.99   	PredLongTermGain+2.84
# 146 	CurrClose:216.24   	PredCurrGain+212.6043243   	ActualGain+1.01   	PredLongTermGain+2.92
# 147 	CurrClose:215.68   	PredCurrGain+212.6472321   	ActualGain+1.00   	PredLongTermGain+2.91
# 148 	CurrClose:212.53   	PredCurrGain+212.8023071   	ActualGain+0.99   	PredLongTermGain+2.81
# 149 	CurrClose:213.56   	PredCurrGain+212.1829224   	ActualGain+1.00   	PredLongTermGain+2.84
# 150 	CurrClose:210.29   	PredCurrGain+211.4904022   	ActualGain+0.98   	PredLongTermGain+2.75
# 151 	CurrClose:207.64   	PredCurrGain+210.6647491   	ActualGain+0.99   	PredLongTermGain+2.67
# 152 	CurrClose:217.83   	PredCurrGain+208.2994690   	ActualGain+1.05   	PredLongTermGain+2.96
# 153 	CurrClose:222.84   	PredCurrGain+210.5815430   	ActualGain+1.02   	PredLongTermGain+3.12
# 154 	CurrClose:225.85   	PredCurrGain+216.3101959   	ActualGain+1.01   	PredLongTermGain+3.21
# 155 	CurrClose:233.06   	PredCurrGain+220.0775909   	ActualGain+1.03   	PredLongTermGain+3.44
# 156 	CurrClose:233.68   	PredCurrGain+225.8763428   	ActualGain+1.00   	PredLongTermGain+3.46
# 157 	CurrClose:235.12   	PredCurrGain+229.8009796   	ActualGain+1.01   	PredLongTermGain+3.51
# 158 	CurrClose:236.05   	PredCurrGain+231.3697968   	ActualGain+1.00   	PredLongTermGain+3.54
# 159 	CurrClose:232.05   	PredCurrGain+233.0969238   	ActualGain+0.98   	PredLongTermGain+3.41
# 160 	CurrClose:233.36   	PredCurrGain+232.7569427   	ActualGain+1.01   	PredLongTermGain+3.45
# 161 	CurrClose:233.79   	PredCurrGain+231.6463776   	ActualGain+1.00   	PredLongTermGain+3.46
# 162 	CurrClose:222.68   	PredCurrGain+231.1507263   	ActualGain+0.95   	PredLongTermGain+3.09
# 163 	CurrClose:218.44   	PredCurrGain+226.3254852   	ActualGain+0.98   	PredLongTermGain+2.96
# 164 	CurrClose:199.93   	PredCurrGain+221.8175812   	ActualGain+0.92   	PredLongTermGain+2.40
# 165 	CurrClose:213.96   	PredCurrGain+213.5176239   	ActualGain+1.07   	PredLongTermGain+2.77
# 166 	CurrClose:221.74   	PredCurrGain+209.5523376   	ActualGain+1.04   	PredLongTermGain+3.00
# 167 	CurrClose:216.72   	PredCurrGain+212.1350403   	ActualGain+0.98   	PredLongTermGain+2.85
# 168 	CurrClose:217.35   	PredCurrGain+214.1336670   	ActualGain+1.00   	PredLongTermGain+2.87
# 169 	CurrClose:216.96   	PredCurrGain+213.8453522   	ActualGain+1.00   	PredLongTermGain+2.86
# 170 	CurrClose:213.62   	PredCurrGain+213.5736237   	ActualGain+0.98   	PredLongTermGain+2.76
# 171 	CurrClose:216.55   	PredCurrGain+212.2332611   	ActualGain+1.01   	PredLongTermGain+2.84
# 172 	CurrClose:201.09   	PredCurrGain+213.1981506   	ActualGain+0.93   	PredLongTermGain+2.38
# 173 	CurrClose:198.22   	PredCurrGain+204.4464569   	ActualGain+0.99   	PredLongTermGain+2.31
# 174 	CurrClose:190.97   	PredCurrGain+199.3875275   	ActualGain+0.96   	PredLongTermGain+2.12
# 175 	CurrClose:192.74   	PredCurrGain+192.6165924   	ActualGain+1.01   	PredLongTermGain+2.16
# 176 	CurrClose:184.14   	PredCurrGain+189.1304932   	ActualGain+0.96   	PredLongTermGain+1.95
# 177 	CurrClose:184.72   	PredCurrGain+185.1018372   	ActualGain+1.00   	PredLongTermGain+1.96
# 178 	CurrClose:179.56   	PredCurrGain+182.0175781   	ActualGain+0.97   	PredLongTermGain+1.84
# 179 	CurrClose:181.49   	PredCurrGain+179.5538635   	ActualGain+1.01   	PredLongTermGain+1.88
# 180 	CurrClose:173.02   	PredCurrGain+177.8180542   	ActualGain+0.95   	PredLongTermGain+1.68
# 181 	CurrClose:171.83   	PredCurrGain+173.7969666   	ActualGain+0.99   	PredLongTermGain+1.66
# 182 	CurrClose:171.36   	PredCurrGain+171.1064453   	ActualGain+1.00   	PredLongTermGain+1.65
# 183 	CurrClose:183.41   	PredCurrGain+168.7512817   	ActualGain+1.07   	PredLongTermGain+1.91
# 184 	CurrClose:184.56   	PredCurrGain+172.5928345   	ActualGain+1.01   	PredLongTermGain+1.93
# 185 	CurrClose:183.48   	PredCurrGain+177.5154266   	ActualGain+0.99   	PredLongTermGain+1.91
# 186 	CurrClose:182.93   	PredCurrGain+179.6390381   	ActualGain+1.00   	PredLongTermGain+1.90
# 187 	CurrClose:189.22   	PredCurrGain+180.2909546   	ActualGain+1.03   	PredLongTermGain+2.04
# 188 	CurrClose:188.89   	PredCurrGain+182.9352875   	ActualGain+1.00   	PredLongTermGain+2.03
# 189 	CurrClose:195.39   	PredCurrGain+185.0415497   	ActualGain+1.03   	PredLongTermGain+2.19
# 190 	CurrClose:181.49   	PredCurrGain+188.8297577   	ActualGain+0.93   	PredLongTermGain+1.84
# 191 	CurrClose:182.58   	PredCurrGain+189.1513672   	ActualGain+1.01   	PredLongTermGain+1.87
# 192 	CurrClose:188.41   	PredCurrGain+185.1536102   	ActualGain+1.03   	PredLongTermGain+2.00
# 193 	CurrClose:189.28   	PredCurrGain+183.6283569   	ActualGain+1.00   	PredLongTermGain+2.02
# 194 	CurrClose:184.23   	PredCurrGain+184.9160004   	ActualGain+0.97   	PredLongTermGain+1.90
# 195 	CurrClose:182.41   	PredCurrGain+183.8583374   	ActualGain+0.99   	PredLongTermGain+1.86
# 196 	CurrClose:177.12   	PredCurrGain+181.1078339   	ActualGain+0.97   	PredLongTermGain+1.74
# 197 	CurrClose:171.67   	PredCurrGain+177.3947754   	ActualGain+0.97   	PredLongTermGain+1.62
# 198 	CurrClose:168.92   	PredCurrGain+174.0619049   	ActualGain+0.98   	PredLongTermGain+1.56
# 199 	CurrClose:168.70   	PredCurrGain+170.3460388   	ActualGain+1.00   	PredLongTermGain+1.55
# 200 	CurrClose:175.76   	PredCurrGain+168.0621796   	ActualGain+1.04   	PredLongTermGain+1.70
# 201 	CurrClose:172.42   	PredCurrGain+168.6275482   	ActualGain+0.98   	PredLongTermGain+1.63
# 202 	CurrClose:169.55   	PredCurrGain+169.3739319   	ActualGain+0.98   	PredLongTermGain+1.57
# 203 	CurrClose:170.07   	PredCurrGain+168.7389221   	ActualGain+1.00   	PredLongTermGain+1.58
# 204 	CurrClose:174.27   	PredCurrGain+167.5053558   	ActualGain+1.02   	PredLongTermGain+1.66
# 205 	CurrClose:170.13   	PredCurrGain+169.0052338   	ActualGain+0.98   	PredLongTermGain+1.58
# 206 	CurrClose:170.28   	PredCurrGain+169.6726227   	ActualGain+1.00   	PredLongTermGain+1.58
# 207 	CurrClose:171.12   	PredCurrGain+168.9570618   	ActualGain+1.00   	PredLongTermGain+1.60
# 208 	CurrClose:183.08   	PredCurrGain+169.0864258   	ActualGain+1.07   	PredLongTermGain+1.85
# 209 	CurrClose:185.03   	PredCurrGain+176.2263336   	ActualGain+1.01   	PredLongTermGain+1.89
# 210 	CurrClose:188.79   	PredCurrGain+180.1445312   	ActualGain+1.02   	PredLongTermGain+1.98
# 211 	CurrClose:197.69   	PredCurrGain+183.8713074   	ActualGain+1.05   	PredLongTermGain+2.19
# 212 	CurrClose:194.41   	PredCurrGain+190.2325897   	ActualGain+0.98   	PredLongTermGain+2.11
# 213 	CurrClose:195.20   	PredCurrGain+192.7015533   	ActualGain+1.00   	PredLongTermGain+2.12
# 214 	CurrClose:195.05   	PredCurrGain+195.4038391   	ActualGain+1.00   	PredLongTermGain+2.12
# 215 	CurrClose:202.37   	PredCurrGain+194.1672821   	ActualGain+1.04   	PredLongTermGain+2.30
# 216 	CurrClose:204.20   	PredCurrGain+194.8234253   	ActualGain+1.01   	PredLongTermGain+2.35
# 217 	CurrClose:205.80   	PredCurrGain+198.0672607   	ActualGain+1.01   	PredLongTermGain+2.39
# 218 	CurrClose:203.28   	PredCurrGain+200.1271362   	ActualGain+0.99   	PredLongTermGain+2.32
# 219 	CurrClose:208.40   	PredCurrGain+201.0074768   	ActualGain+1.03   	PredLongTermGain+2.45
# 220 	CurrClose:205.04   	PredCurrGain+202.6907806   	ActualGain+0.98   	PredLongTermGain+2.37
# 221 	CurrClose:204.68   	PredCurrGain+203.7974396   	ActualGain+1.00   	PredLongTermGain+2.36
# 222 	CurrClose:201.28   	PredCurrGain+203.1343079   	ActualGain+0.98   	PredLongTermGain+2.27
# 223 	CurrClose:203.61   	PredCurrGain+201.6140747   	ActualGain+1.01   	PredLongTermGain+2.33
# 224 	CurrClose:202.32   	PredCurrGain+201.1757660   	ActualGain+0.99   	PredLongTermGain+2.29
# 225 	CurrClose:205.46   	PredCurrGain+200.9049530   	ActualGain+1.02   	PredLongTermGain+2.37
# 226 	CurrClose:207.71   	PredCurrGain+202.1195679   	ActualGain+1.01   	PredLongTermGain+2.43
# 227 	CurrClose:218.77   	PredCurrGain+203.7506714   	ActualGain+1.05   	PredLongTermGain+2.72
# 228 	CurrClose:220.47   	PredCurrGain+213.1672821   	ActualGain+1.01   	PredLongTermGain+2.77
# 229 	CurrClose:213.79   	PredCurrGain+216.8638306   	ActualGain+0.97   	PredLongTermGain+2.58
# 230 	CurrClose:213.20   	PredCurrGain+216.1429596   	ActualGain+1.00   	PredLongTermGain+2.57
# 231 	CurrClose:210.23   	PredCurrGain+213.7793884   	ActualGain+0.99   	PredLongTermGain+2.49
# 232 	CurrClose:209.18   	PredCurrGain+211.0540924   	ActualGain+1.00   	PredLongTermGain+2.46
# 233 	CurrClose:199.65   	PredCurrGain+208.8773041   	ActualGain+0.95   	PredLongTermGain+2.21
# 234 	CurrClose:197.60   	PredCurrGain+204.6935883   	ActualGain+0.99   	PredLongTermGain+2.16
# 235 	CurrClose:197.28   	PredCurrGain+199.7517548   	ActualGain+1.00   	PredLongTermGain+2.15
# 236 	CurrClose:197.57   	PredCurrGain+196.6811829   	ActualGain+1.00   	PredLongTermGain+2.15
# 237 	CurrClose:197.35   	PredCurrGain+195.0869904   	ActualGain+1.00   	PredLongTermGain+2.15
# 238 	CurrClose:197.59   	PredCurrGain+194.9773102   	ActualGain+1.00   	PredLongTermGain+2.15
# 239 	CurrClose:204.60   	PredCurrGain+195.0142212   	ActualGain+1.04   	PredLongTermGain+2.33
# 240 	CurrClose:201.69   	PredCurrGain+197.7445984   	ActualGain+0.99   	PredLongTermGain+2.25
# 241 	CurrClose:193.69   	PredCurrGain+200.0957031   	ActualGain+0.96   	PredLongTermGain+2.05
# 242 	CurrClose:187.25   	PredCurrGain+198.3143616   	ActualGain+0.97   	PredLongTermGain+1.90
# 243 	CurrClose:188.29   	PredCurrGain+193.0214996   	ActualGain+1.01   	PredLongTermGain+1.92
# 244 	CurrClose:185.84   	PredCurrGain+188.8258514   	ActualGain+0.99   	PredLongTermGain+1.87
# 245 	CurrClose:187.44   	PredCurrGain+185.9079895   	ActualGain+1.01   	PredLongTermGain+1.90
# 246 	CurrClose:185.68   	PredCurrGain+185.0483704   	ActualGain+0.99   	PredLongTermGain+1.86
# 247 	CurrClose:185.20   	PredCurrGain+184.8836365   	ActualGain+1.00   	PredLongTermGain+1.85
# 248 	CurrClose:185.66   	PredCurrGain+184.0392609   	ActualGain+1.00   	PredLongTermGain+1.86
# 249 	CurrClose:187.98   	PredCurrGain+183.4961090   	ActualGain+1.01   	PredLongTermGain+1.91
# 250 	CurrClose:190.82   	PredCurrGain+185.1551666   	ActualGain+1.02   	PredLongTermGain+1.98
# 251 	CurrClose:191.69   	PredCurrGain+186.8133545   	ActualGain+1.00   	PredLongTermGain+2.00
# 252 	CurrClose:190.87   	PredCurrGain+187.9084015   	ActualGain+1.00   	PredLongTermGain+1.98
# 253 	CurrClose:186.16   	PredCurrGain+189.0075226   	ActualGain+0.98   	PredLongTermGain+1.87
# 254 	CurrClose:186.10   	PredCurrGain+187.7572479   	ActualGain+1.00   	PredLongTermGain+1.87
# 255 	CurrClose:191.50   	PredCurrGain+186.5159760   	ActualGain+1.03   	PredLongTermGain+1.99
# 256 	CurrClose:189.91   	PredCurrGain+187.1654510   	ActualGain+0.99   	PredLongTermGain+1.95
# 257 	CurrClose:187.41   	PredCurrGain+188.6005859   	ActualGain+0.99   	PredLongTermGain+1.89
# 258 	CurrClose:195.19   	PredCurrGain+187.9025879   	ActualGain+1.04   	PredLongTermGain+2.07
# 259 	CurrClose:193.45   	PredCurrGain+189.7234650   	ActualGain+0.99   	PredLongTermGain+2.03
# 260 	CurrClose:196.85   	PredCurrGain+192.0628204   	ActualGain+1.02   	PredLongTermGain+2.11
# 261 	CurrClose:193.48   	PredCurrGain+193.1161804   	ActualGain+0.98   	PredLongTermGain+2.03
# 262 	CurrClose:190.96   	PredCurrGain+193.3471680   	ActualGain+0.99   	PredLongTermGain+1.97
# 263 	CurrClose:193.45   	PredCurrGain+192.1251373   	ActualGain+1.01   	PredLongTermGain+2.03
# 264 	CurrClose:192.39   	PredCurrGain+191.2397308   	ActualGain+0.99   	PredLongTermGain+2.00
# 265 	CurrClose:195.70   	PredCurrGain+191.2674103   	ActualGain+1.02   	PredLongTermGain+2.08
# 266 	CurrClose:195.55   	PredCurrGain+192.0829773   	ActualGain+1.00   	PredLongTermGain+2.08
# 267 	CurrClose:194.26   	PredCurrGain+192.8874207   	ActualGain+0.99   	PredLongTermGain+2.05
# 268 	CurrClose:193.78   	PredCurrGain+193.5167694   	ActualGain+1.00   	PredLongTermGain+2.03
# 269 	CurrClose:201.27   	PredCurrGain+193.2435455   	ActualGain+1.04   	PredLongTermGain+2.21
# 270 	CurrClose:200.18   	PredCurrGain+195.7182007   	ActualGain+0.99   	PredLongTermGain+2.18
# 271 	CurrClose:202.63   	PredCurrGain+197.3222961   	ActualGain+1.01   	PredLongTermGain+2.24
# 272 	CurrClose:202.31   	PredCurrGain+199.6822052   	ActualGain+1.00   	PredLongTermGain+2.24
# 273 	CurrClose:201.36   	PredCurrGain+201.1326447   	ActualGain+1.00   	PredLongTermGain+2.21
# 274 	CurrClose:203.26   	PredCurrGain+201.5026550   	ActualGain+1.01   	PredLongTermGain+2.26
# 275 	CurrClose:209.11   	PredCurrGain+201.7388153   	ActualGain+1.03   	PredLongTermGain+2.41
# 276 	CurrClose:209.87   	PredCurrGain+204.1093597   	ActualGain+1.00   	PredLongTermGain+2.43
# 277 	CurrClose:211.81   	PredCurrGain+206.3671570   	ActualGain+1.01   	PredLongTermGain+2.48
# 278 	CurrClose:210.94   	PredCurrGain+208.6091919   	ActualGain+1.00   	PredLongTermGain+2.45
# 279 	CurrClose:211.81   	PredCurrGain+209.5328369   	ActualGain+1.00   	PredLongTermGain+2.48
# 280 	CurrClose:210.44   	PredCurrGain+210.6132965   	ActualGain+0.99   	PredLongTermGain+2.44
# 281 	CurrClose:209.31   	PredCurrGain+210.7988129   	ActualGain+0.99   	PredLongTermGain+2.41
# 282 	CurrClose:212.49   	PredCurrGain+210.2118530   	ActualGain+1.02   	PredLongTermGain+2.49
# 283 	CurrClose:208.83   	PredCurrGain+209.8997498   	ActualGain+0.98   	PredLongTermGain+2.40
# 284 	CurrClose:204.62   	PredCurrGain+209.2588348   	ActualGain+0.98   	PredLongTermGain+2.29
# 285 	CurrClose:201.95   	PredCurrGain+206.8745117   	ActualGain+0.99   	PredLongTermGain+2.22
# 286 	CurrClose:204.15   	PredCurrGain+203.8955536   	ActualGain+1.01   	PredLongTermGain+2.28
# 287 	CurrClose:201.73   	PredCurrGain+202.5751953   	ActualGain+0.99   	PredLongTermGain+2.21
# 288 	CurrClose:199.70   	PredCurrGain+201.5659637   	ActualGain+0.99   	PredLongTermGain+2.16
# 289 	CurrClose:193.75   	PredCurrGain+199.3077850   	ActualGain+0.97   	PredLongTermGain+2.02
# 290 	CurrClose:195.25   	PredCurrGain+197.2617950   	ActualGain+1.01   	PredLongTermGain+2.05
# 291 	CurrClose:195.65   	PredCurrGain+194.2590027   	ActualGain+1.00   	PredLongTermGain+2.06
# 292 	CurrClose:194.87   	PredCurrGain+193.1176758   	ActualGain+1.00   	PredLongTermGain+2.05
# 293 	CurrClose:192.94   	PredCurrGain+192.1046295   	ActualGain+0.99   	PredLongTermGain+2.00
# 294 	CurrClose:191.39   	PredCurrGain+191.6484222   	ActualGain+0.99   	PredLongTermGain+1.96
# 295 	CurrClose:194.25   	PredCurrGain+190.8453827   	ActualGain+1.01   	PredLongTermGain+2.03
# 296 	CurrClose:193.49   	PredCurrGain+191.1266479   	ActualGain+1.00   	PredLongTermGain+2.01
# 297 	CurrClose:187.94   	PredCurrGain+191.7814331   	ActualGain+0.97   	PredLongTermGain+1.88
# 298 	CurrClose:183.80   	PredCurrGain+190.4611053   	ActualGain+0.98   	PredLongTermGain+1.79
# 299 	CurrClose:187.88   	PredCurrGain+187.3343811   	ActualGain+1.02   	PredLongTermGain+1.88
# 300 	CurrClose:187.11   	PredCurrGain+185.4891510   	ActualGain+1.00   	PredLongTermGain+1.86
# 301 	CurrClose:189.16   	PredCurrGain+185.7627563   	ActualGain+1.01   	PredLongTermGain+1.91
# 302 	CurrClose:190.69   	PredCurrGain+185.9852600   	ActualGain+1.01   	PredLongTermGain+1.94
# 303 	CurrClose:188.66   	PredCurrGain+188.0341644   	ActualGain+0.99   	PredLongTermGain+1.89
# 304 	CurrClose:187.29   	PredCurrGain+188.7178345   	ActualGain+0.99   	PredLongTermGain+1.86
# 305 	CurrClose:184.43   	PredCurrGain+187.7391205   	ActualGain+0.98   	PredLongTermGain+1.80
# 306 	CurrClose:184.90   	PredCurrGain+186.1381836   	ActualGain+1.00   	PredLongTermGain+1.81
# 307 	CurrClose:190.68   	PredCurrGain+185.2436676   	ActualGain+1.03   	PredLongTermGain+1.94
# 308 	CurrClose:194.05   	PredCurrGain+186.6647339   	ActualGain+1.02   	PredLongTermGain+2.01
# 309 	CurrClose:193.09   	PredCurrGain+189.5716095   	ActualGain+1.00   	PredLongTermGain+1.99
# 310 	CurrClose:191.87   	PredCurrGain+191.3912811   	ActualGain+0.99   	PredLongTermGain+1.96
# 311 	CurrClose:188.84   	PredCurrGain+191.7205048   	ActualGain+0.98   	PredLongTermGain+1.89
# 312 	CurrClose:189.33   	PredCurrGain+189.9102631   	ActualGain+1.00   	PredLongTermGain+1.91
# 313 	CurrClose:186.90   	PredCurrGain+188.7723236   	ActualGain+0.99   	PredLongTermGain+1.85
# 314 	CurrClose:187.05   	PredCurrGain+187.4859924   	ActualGain+1.00   	PredLongTermGain+1.85
# 315 	CurrClose:186.82   	PredCurrGain+186.5771790   	ActualGain+1.00   	PredLongTermGain+1.85
# 316 	CurrClose:190.67   	PredCurrGain+185.9956665   	ActualGain+1.02   	PredLongTermGain+1.93
# 317 	CurrClose:189.66   	PredCurrGain+187.2188263   	ActualGain+0.99   	PredLongTermGain+1.91
# 318 	CurrClose:190.57   	PredCurrGain+188.3826752   	ActualGain+1.00   	PredLongTermGain+1.93
# 319 	CurrClose:189.45   	PredCurrGain+189.3211212   	ActualGain+0.99   	PredLongTermGain+1.91
# 320 	CurrClose:189.49   	PredCurrGain+189.5136108   	ActualGain+1.00   	PredLongTermGain+1.91
# 321 	CurrClose:192.37   	PredCurrGain+189.4233093   	ActualGain+1.02   	PredLongTermGain+1.97
# 322 	CurrClose:190.26   	PredCurrGain+190.1142273   	ActualGain+0.99   	PredLongTermGain+1.92
# 323 	CurrClose:189.43   	PredCurrGain+190.2201538   	ActualGain+1.00   	PredLongTermGain+1.90
# 324 	CurrClose:189.11   	PredCurrGain+189.6975403   	ActualGain+1.00   	PredLongTermGain+1.90
# 325 	CurrClose:192.24   	PredCurrGain+188.9973450   	ActualGain+1.02   	PredLongTermGain+1.97
# 326 	CurrClose:196.15   	PredCurrGain+189.5945129   	ActualGain+1.02   	PredLongTermGain+2.06
# 327 	CurrClose:203.49   	PredCurrGain+191.9799500   	ActualGain+1.04   	PredLongTermGain+2.23
# 328 	CurrClose:202.19   	PredCurrGain+196.9130096   	ActualGain+0.99   	PredLongTermGain+2.20
# 329 	CurrClose:205.15   	PredCurrGain+199.9153748   	ActualGain+1.01   	PredLongTermGain+2.27
# 330 	CurrClose:207.55   	PredCurrGain+202.6536865   	ActualGain+1.01   	PredLongTermGain+2.33
# 331 	CurrClose:202.11   	PredCurrGain+205.0131683   	ActualGain+0.97   	PredLongTermGain+2.19
# 332 	CurrClose:198.70   	PredCurrGain+204.3794556   	ActualGain+0.98   	PredLongTermGain+2.11
# 333 	CurrClose:203.63   	PredCurrGain+201.8435364   	ActualGain+1.02   	PredLongTermGain+2.23
# 334 	CurrClose:202.09   	PredCurrGain+201.0840912   	ActualGain+0.99   	PredLongTermGain+2.19
# 335 	CurrClose:202.19   	PredCurrGain+200.3832397   	ActualGain+1.00   	PredLongTermGain+2.19
# 336 	CurrClose:203.64   	PredCurrGain+200.4478607   	ActualGain+1.01   	PredLongTermGain+2.23
# 337 	CurrClose:201.66   	PredCurrGain+200.8627319   	ActualGain+0.99   	PredLongTermGain+2.18
# 338 	CurrClose:201.99   	PredCurrGain+201.2255859   	ActualGain+1.00   	PredLongTermGain+2.19
# 339 	CurrClose:201.15   	PredCurrGain+201.0813141   	ActualGain+1.00   	PredLongTermGain+2.17
# 340 	CurrClose:200.92   	PredCurrGain+200.8274231   	ActualGain+1.00   	PredLongTermGain+2.16
# 341 	CurrClose:202.22   	PredCurrGain+200.5364532   	ActualGain+1.01   	PredLongTermGain+2.19
# 342 	CurrClose:208.06   	PredCurrGain+200.5554810   	ActualGain+1.03   	PredLongTermGain+2.34
# 343 	CurrClose:206.11   	PredCurrGain+202.6842194   	ActualGain+0.99   	PredLongTermGain+2.29
# 344 	CurrClose:210.46   	PredCurrGain+204.6499023   	ActualGain+1.02   	PredLongTermGain+2.40
# 345 	CurrClose:214.71   	PredCurrGain+206.4190826   	ActualGain+1.02   	PredLongTermGain+2.50
# 346 	CurrClose:213.54   	PredCurrGain+210.2208252   	ActualGain+0.99   	PredLongTermGain+2.47
# 347 	CurrClose:213.46   	PredCurrGain+212.7039337   	ActualGain+1.00   	PredLongTermGain+2.47
# 348 	CurrClose:213.93   	PredCurrGain+212.8997955   	ActualGain+1.00   	PredLongTermGain+2.48
# 349 	CurrClose:213.86   	PredCurrGain+212.9356689   	ActualGain+1.00   	PredLongTermGain+2.48
# 350 	CurrClose:211.09   	PredCurrGain+212.8646698   	ActualGain+0.99   	PredLongTermGain+2.41
# 351 	CurrClose:210.53   	PredCurrGain+212.0621796   	ActualGain+1.00   	PredLongTermGain+2.39
# 352 	CurrClose:209.86   	PredCurrGain+210.5590363   	ActualGain+1.00   	PredLongTermGain+2.38
# 353 	CurrClose:213.24   	PredCurrGain+209.8358459   	ActualGain+1.02   	PredLongTermGain+2.46
# 354 	CurrClose:230.07   	PredCurrGain+210.5674744   	ActualGain+1.08   	PredLongTermGain+2.90
# 355 	CurrClose:240.63   	PredCurrGain+220.0305328   	ActualGain+1.05   	PredLongTermGain+3.20
# 356 	CurrClose:236.89   	PredCurrGain+229.5348816   	ActualGain+0.98   	PredLongTermGain+3.09
# 357 	CurrClose:243.54   	PredCurrGain+234.4824677   	ActualGain+1.03   	PredLongTermGain+3.28
# 358 	CurrClose:242.79   	PredCurrGain+238.6108551   	ActualGain+1.00   	PredLongTermGain+3.26
# 359 	CurrClose:237.84   	PredCurrGain+241.5009918   	ActualGain+0.98   	PredLongTermGain+3.11
# 360 	CurrClose:238.52   	PredCurrGain+240.3619537   	ActualGain+1.00   	PredLongTermGain+3.13
# 361 	CurrClose:238.43   	PredCurrGain+238.4908447   	ActualGain+1.00   	PredLongTermGain+3.13
# 362 	CurrClose:233.98   	PredCurrGain+237.7326813   	ActualGain+0.98   	PredLongTermGain+3.00
# 363 	CurrClose:235.19   	PredCurrGain+235.8134460   	ActualGain+1.01   	PredLongTermGain+3.03
# 364 	CurrClose:236.14   	PredCurrGain+234.2233429   	ActualGain+1.00   	PredLongTermGain+3.06
# 365 	CurrClose:238.71   	PredCurrGain+233.8082733   	ActualGain+1.01   	PredLongTermGain+3.14
# 366 	CurrClose:236.52   	PredCurrGain+235.1728973   	ActualGain+0.99   	PredLongTermGain+3.07
# 367 	CurrClose:237.74   	PredCurrGain+235.8551483   	ActualGain+1.01   	PredLongTermGain+3.11
# 368 	CurrClose:236.55   	PredCurrGain+236.1400604   	ActualGain+1.00   	PredLongTermGain+3.07
# 369 	CurrClose:237.01   	PredCurrGain+236.3846283   	ActualGain+1.00   	PredLongTermGain+3.08
# 370 	CurrClose:240.76   	PredCurrGain+236.0514221   	ActualGain+1.02   	PredLongTermGain+3.19
# 371 	CurrClose:244.89   	PredCurrGain+237.2664642   	ActualGain+1.02   	PredLongTermGain+3.32
# 372 	CurrClose:246.21   	PredCurrGain+240.0587158   	ActualGain+1.01   	PredLongTermGain+3.36
# 373 	CurrClose:248.20   	PredCurrGain+243.8361206   	ActualGain+1.01   	PredLongTermGain+3.42
# 374 	CurrClose:249.64   	PredCurrGain+246.1052704   	ActualGain+1.01   	PredLongTermGain+3.46
# 375 	CurrClose:247.77   	PredCurrGain+247.4009399   	ActualGain+0.99   	PredLongTermGain+3.41
# 376 	CurrClose:255.08   	PredCurrGain+247.6979523   	ActualGain+1.03   	PredLongTermGain+3.63
# 377 	CurrClose:254.26   	PredCurrGain+249.7693481   	ActualGain+1.00   	PredLongTermGain+3.60
# 378 	CurrClose:252.75   	PredCurrGain+252.2483826   	ActualGain+0.99   	PredLongTermGain+3.56
# 379 	CurrClose:242.62   	PredCurrGain+252.5365143   	ActualGain+0.96   	PredLongTermGain+3.24
# 380 	CurrClose:244.99   	PredCurrGain+248.8654633   	ActualGain+1.01   	PredLongTermGain+3.31
# 381 	CurrClose:242.57   	PredCurrGain+244.7602539   	ActualGain+0.99   	PredLongTermGain+3.23
# 382 	CurrClose:242.65   	PredCurrGain+243.2276611   	ActualGain+1.00   	PredLongTermGain+3.24
# 383 	CurrClose:240.64   	PredCurrGain+241.8171997   	ActualGain+0.99   	PredLongTermGain+3.18
# 384 	CurrClose:242.67   	PredCurrGain+240.6816711   	ActualGain+1.01   	PredLongTermGain+3.24
# 385 	CurrClose:243.74   	PredCurrGain+240.5190277   	ActualGain+1.00   	PredLongTermGain+3.27
# 386 	CurrClose:244.60   	PredCurrGain+241.5812073   	ActualGain+1.00   	PredLongTermGain+3.29
# 387 	CurrClose:241.56   	PredCurrGain+242.6717682   	ActualGain+0.99   	PredLongTermGain+3.20
# 388 	CurrClose:242.30   	PredCurrGain+242.8121948   	ActualGain+1.00   	PredLongTermGain+3.22
# 389 	CurrClose:242.21   	PredCurrGain+242.2160492   	ActualGain+1.00   	PredLongTermGain+3.22
# 390 	CurrClose:241.13   	PredCurrGain+242.2321777   	ActualGain+1.00   	PredLongTermGain+3.19
# 391 	CurrClose:239.73   	PredCurrGain+241.6378479   	ActualGain+0.99   	PredLongTermGain+3.15
# 392 	CurrClose:241.30   	PredCurrGain+240.8006592   	ActualGain+1.01   	PredLongTermGain+3.19
# 393 	CurrClose:240.39   	PredCurrGain+240.2870178   	ActualGain+1.00   	PredLongTermGain+3.17
# 394 	CurrClose:231.63   	PredCurrGain+240.1569366   	ActualGain+0.96   	PredLongTermGain+2.91
# 395 	CurrClose:234.55   	PredCurrGain+237.1553955   	ActualGain+1.01   	PredLongTermGain+2.99
# 396 	CurrClose:231.68   	PredCurrGain+233.9361420   	ActualGain+0.99   	PredLongTermGain+2.91
# 397 	CurrClose:228.33   	PredCurrGain+232.3971252   	ActualGain+0.99   	PredLongTermGain+2.81
# 398 	CurrClose:228.02   	PredCurrGain+229.9168854   	ActualGain+1.00   	PredLongTermGain+2.80
# 399 	CurrClose:228.99   	PredCurrGain+227.9450684   	ActualGain+1.00   	PredLongTermGain+2.83
# 400 	CurrClose:234.25   	PredCurrGain+227.3677521   	ActualGain+1.02   	PredLongTermGain+2.98
# 401 	CurrClose:231.51   	PredCurrGain+229.3718567   	ActualGain+0.99   	PredLongTermGain+2.90
# 402 	CurrClose:230.47   	PredCurrGain+230.9154205   	ActualGain+1.00   	PredLongTermGain+2.87
# 403 	CurrClose:234.03   	PredCurrGain+231.0235596   	ActualGain+1.02   	PredLongTermGain+2.97
# 404 	CurrClose:241.87   	PredCurrGain+232.6941376   	ActualGain+1.03   	PredLongTermGain+3.19
# 405 	CurrClose:243.84   	PredCurrGain+235.9797668   	ActualGain+1.01   	PredLongTermGain+3.25
# 406 	CurrClose:242.03   	PredCurrGain+239.5012817   	ActualGain+0.99   	PredLongTermGain+3.20
# 407 	CurrClose:242.99   	PredCurrGain+241.5223846   	ActualGain+1.00   	PredLongTermGain+3.23
# 408 	CurrClose:244.97   	PredCurrGain+242.2745819   	ActualGain+1.01   	PredLongTermGain+3.28
# 409 	CurrClose:250.11   	PredCurrGain+243.0789032   	ActualGain+1.02   	PredLongTermGain+3.44
# 410 	CurrClose:252.75   	PredCurrGain+246.3767548   	ActualGain+1.01   	PredLongTermGain+3.52
# 411 	CurrClose:252.39   	PredCurrGain+249.2782135   	ActualGain+1.00   	PredLongTermGain+3.51
# 412 	CurrClose:248.89   	PredCurrGain+251.6270294   	ActualGain+0.99   	PredLongTermGain+3.40
# 413 	CurrClose:244.16   	PredCurrGain+250.9092102   	ActualGain+0.98   	PredLongTermGain+3.26
# 414 	CurrClose:245.12   	PredCurrGain+247.7124329   	ActualGain+1.00   	PredLongTermGain+3.28
# 415 	CurrClose:240.66   	PredCurrGain+245.1545563   	ActualGain+0.98   	PredLongTermGain+3.15
# 416 	CurrClose:239.76   	PredCurrGain+242.7449951   	ActualGain+1.00   	PredLongTermGain+3.12
# 417 	CurrClose:249.78   	PredCurrGain+240.3298187   	ActualGain+1.04   	PredLongTermGain+3.42
# 418 	CurrClose:244.29   	PredCurrGain+242.4883728   	ActualGain+0.98   	PredLongTermGain+3.25
# 419 	CurrClose:248.17   	PredCurrGain+244.4044800   	ActualGain+1.02   	PredLongTermGain+3.36
# 420 	CurrClose:246.48   	PredCurrGain+245.5166931   	ActualGain+0.99   	PredLongTermGain+3.31
# 421 	CurrClose:247.41   	PredCurrGain+246.3952942   	ActualGain+1.00   	PredLongTermGain+3.34
# 422 	CurrClose:251.00   	PredCurrGain+246.7784119   	ActualGain+1.01   	PredLongTermGain+3.45
# 423 	CurrClose:241.12   	PredCurrGain+248.4112091   	ActualGain+0.96   	PredLongTermGain+3.14
# 424 	CurrClose:240.99   	PredCurrGain+246.9047699   	ActualGain+1.00   	PredLongTermGain+3.14
# 425 	CurrClose:233.81   	PredCurrGain+242.9420929   	ActualGain+0.97   	PredLongTermGain+2.93
# 426 	CurrClose:235.98   	PredCurrGain+237.6494598   	ActualGain+1.01   	PredLongTermGain+2.99
# 427 	CurrClose:235.24   	PredCurrGain+234.5856476   	ActualGain+1.00   	PredLongTermGain+2.97
# 428 	CurrClose:235.75   	PredCurrGain+233.6443787   	ActualGain+1.00   	PredLongTermGain+2.98
# 429 	CurrClose:231.18   	PredCurrGain+233.2034454   	ActualGain+0.98   	PredLongTermGain+2.85
# 430 	CurrClose:229.37   	PredCurrGain+232.4338684   	ActualGain+0.99   	PredLongTermGain+2.80
# 431 	CurrClose:229.78   	PredCurrGain+230.3374939   	ActualGain+1.00   	PredLongTermGain+2.82
# 432 	CurrClose:233.20   	PredCurrGain+229.3425293   	ActualGain+1.01   	PredLongTermGain+2.91
# 433 	CurrClose:230.97   	PredCurrGain+230.1110992   	ActualGain+0.99   	PredLongTermGain+2.85
# 434 	CurrClose:235.21   	PredCurrGain+230.5277100   	ActualGain+1.02   	PredLongTermGain+2.96
# 435 	CurrClose:236.29   	PredCurrGain+231.7705994   	ActualGain+1.00   	PredLongTermGain+2.99
# 436 	CurrClose:238.17   	PredCurrGain+233.2433472   	ActualGain+1.01   	PredLongTermGain+3.05
# 437 	CurrClose:238.16   	PredCurrGain+235.0173950   	ActualGain+1.00   	PredLongTermGain+3.05
# 438 	CurrClose:235.55   	PredCurrGain+237.1512909   	ActualGain+0.99   	PredLongTermGain+2.97
# 439 	CurrClose:232.70   	PredCurrGain+236.7322998   	ActualGain+0.99   	PredLongTermGain+2.89
# 440 	CurrClose:224.61   	PredCurrGain+235.2505035   	ActualGain+0.97   	PredLongTermGain+2.67
# 441 	CurrClose:224.95   	PredCurrGain+229.9660339   	ActualGain+1.00   	PredLongTermGain+2.68
# 442 	CurrClose:224.34   	PredCurrGain+225.9435425   	ActualGain+1.00   	PredLongTermGain+2.66
# 443 	CurrClose:219.56   	PredCurrGain+222.9798737   	ActualGain+0.98   	PredLongTermGain+2.53
# 444 	CurrClose:220.70   	PredCurrGain+220.4863892   	ActualGain+1.01   	PredLongTermGain+2.56
# 445 	CurrClose:229.00   	PredCurrGain+218.9259338   	ActualGain+1.04   	PredLongTermGain+2.78
# 446 	CurrClose:228.05   	PredCurrGain+221.9769745   	ActualGain+1.00   	PredLongTermGain+2.75
# 447 	CurrClose:227.59   	PredCurrGain+225.4136658   	ActualGain+1.00   	PredLongTermGain+2.74
# 448 	CurrClose:226.71   	PredCurrGain+227.3141785   	ActualGain+1.00   	PredLongTermGain+2.72
# 449 	CurrClose:227.60   	PredCurrGain+227.4049530   	ActualGain+1.00   	PredLongTermGain+2.74
# 450 	CurrClose:221.74   	PredCurrGain+227.0076294   	ActualGain+0.97   	PredLongTermGain+2.58
# 451 	CurrClose:224.22   	PredCurrGain+224.7612305   	ActualGain+1.01   	PredLongTermGain+2.65
# 452 	CurrClose:223.32   	PredCurrGain+223.0140991   	ActualGain+1.00   	PredLongTermGain+2.62
# 453 	CurrClose:220.65   	PredCurrGain+222.3343201   	ActualGain+0.99   	PredLongTermGain+2.55
# 454 	CurrClose:223.84   	PredCurrGain+221.0760498   	ActualGain+1.01   	PredLongTermGain+2.63
# 455 	CurrClose:222.86   	PredCurrGain+221.0811310   	ActualGain+1.00   	PredLongTermGain+2.61
# 456 	CurrClose:228.50   	PredCurrGain+221.3197174   	ActualGain+1.03   	PredLongTermGain+2.76
# 457 	CurrClose:231.25   	PredCurrGain+223.2771301   	ActualGain+1.01   	PredLongTermGain+2.83
# 458 	CurrClose:231.15   	PredCurrGain+226.3218384   	ActualGain+1.00   	PredLongTermGain+2.83
# 459 	CurrClose:232.73   	PredCurrGain+228.6407928   	ActualGain+1.01   	PredLongTermGain+2.87
# 460 	CurrClose:232.04   	PredCurrGain+230.0533447   	ActualGain+1.00   	PredLongTermGain+2.85
# 461 	CurrClose:231.17   	PredCurrGain+230.9773712   	ActualGain+1.00   	PredLongTermGain+2.83
# 462 	CurrClose:230.69   	PredCurrGain+231.0766296   	ActualGain+1.00   	PredLongTermGain+2.82
# 463 	CurrClose:229.31   	PredCurrGain+230.6848145   	ActualGain+0.99   	PredLongTermGain+2.78
# 464 	CurrClose:229.49   	PredCurrGain+229.9220886   	ActualGain+1.00   	PredLongTermGain+2.78
# 465 	CurrClose:236.54   	PredCurrGain+228.7388306   	ActualGain+1.03   	PredLongTermGain+2.97
# 466 	CurrClose:235.75   	PredCurrGain+231.4145508   	ActualGain+1.00   	PredLongTermGain+2.95
# 467 	CurrClose:235.99   	PredCurrGain+233.5804901   	ActualGain+1.00   	PredLongTermGain+2.96
# 468 	CurrClose:234.34   	PredCurrGain+234.7157898   	ActualGain+0.99   	PredLongTermGain+2.91
# 469 	CurrClose:233.48   	PredCurrGain+234.8447876   	ActualGain+1.00   	PredLongTermGain+2.89
# 470 	CurrClose:232.50   	PredCurrGain+234.2052917   	ActualGain+1.00   	PredLongTermGain+2.86
# 471 	CurrClose:233.93   	PredCurrGain+233.2774506   	ActualGain+1.01   	PredLongTermGain+2.90
# 472 	CurrClose:233.38   	PredCurrGain+232.7457275   	ActualGain+1.00   	PredLongTermGain+2.89
# 473 	CurrClose:237.37   	PredCurrGain+232.7391968   	ActualGain+1.02   	PredLongTermGain+3.00
# 474 	CurrClose:236.64   	PredCurrGain+234.3582001   	ActualGain+1.00   	PredLongTermGain+2.98
# 475 	CurrClose:238.24   	PredCurrGain+235.6429138   	ActualGain+1.01   	PredLongTermGain+3.02
# 476 	CurrClose:236.06   	PredCurrGain+236.5766296   	ActualGain+0.99   	PredLongTermGain+2.96
# 477 	CurrClose:241.48   	PredCurrGain+236.9288788   	ActualGain+1.02   	PredLongTermGain+3.11
# 478 	CurrClose:239.78   	PredCurrGain+240.1365204   	ActualGain+0.99   	PredLongTermGain+3.06
# 479 	CurrClose:239.00   	PredCurrGain+240.0675507   	ActualGain+1.00   	PredLongTermGain+3.04
# 480 	CurrClose:239.23   	PredCurrGain+239.0474548   	ActualGain+1.00   	PredLongTermGain+3.05
# 481 	CurrClose:240.83   	PredCurrGain+238.6793976   	ActualGain+1.01   	PredLongTermGain+3.09
# 482 	CurrClose:239.74   	PredCurrGain+239.0423279   	ActualGain+1.00   	PredLongTermGain+3.06
# 483 	CurrClose:235.93   	PredCurrGain+239.2544098   	ActualGain+0.98   	PredLongTermGain+2.95
# 484 	CurrClose:234.73   	PredCurrGain+238.1875916   	ActualGain+0.99   	PredLongTermGain+2.92
# 485 	CurrClose:233.12   	PredCurrGain+236.0498199   	ActualGain+0.99   	PredLongTermGain+2.87
# 486 	CurrClose:236.85   	PredCurrGain+234.3460083   	ActualGain+1.02   	PredLongTermGain+2.98
# 487 	CurrClose:235.80   	PredCurrGain+234.1794891   	ActualGain+1.00   	PredLongTermGain+2.95
# 488 	CurrClose:233.87   	PredCurrGain+234.3589478   	ActualGain+0.99   	PredLongTermGain+2.89
# 489 	CurrClose:233.64   	PredCurrGain+234.2487640   	ActualGain+1.00   	PredLongTermGain+2.89
# 490 	CurrClose:234.86   	PredCurrGain+233.5212708   	ActualGain+1.01   	PredLongTermGain+2.92
# 491 	CurrClose:230.97   	PredCurrGain+233.4995575   	ActualGain+0.98   	PredLongTermGain+2.81
# 492 	CurrClose:233.60   	PredCurrGain+232.5615997   	ActualGain+1.01   	PredLongTermGain+2.88
# 493 	CurrClose:231.12   	PredCurrGain+232.1029358   	ActualGain+0.99   	PredLongTermGain+2.81
# 494 	CurrClose:229.23   	PredCurrGain+231.6140442   	ActualGain+0.99   	PredLongTermGain+2.76
# 495 	CurrClose:236.54   	PredCurrGain+230.4153442   	ActualGain+1.03   	PredLongTermGain+2.96
# 496 	CurrClose:235.72   	PredCurrGain+231.8139801   	ActualGain+1.00   	PredLongTermGain+2.94
# 497 	CurrClose:235.40   	PredCurrGain+233.9433899   	ActualGain+1.00   	PredLongTermGain+2.93
# 498 	CurrClose:235.54   	PredCurrGain+234.8527832   	ActualGain+1.00   	PredLongTermGain+2.93
# 499 	CurrClose:238.17   	PredCurrGain+235.3560944   	ActualGain+1.01   	PredLongTermGain+3.01
# 500 	CurrClose:237.22   	PredCurrGain+236.5633240   	ActualGain+1.00   	PredLongTermGain+2.98
# 501 	CurrClose:237.40   	PredCurrGain+237.7306824   	ActualGain+1.00   	PredLongTermGain+2.98
# 502 	CurrClose:242.00   	PredCurrGain+237.6567230   	ActualGain+1.02   	PredLongTermGain+3.11
# 503 	CurrClose:243.80   	PredCurrGain+239.2681427   	ActualGain+1.01   	PredLongTermGain+3.17
# 504 	CurrClose:249.55   	PredCurrGain+241.5629272   	ActualGain+1.02   	PredLongTermGain+3.33
# 505 	CurrClose:249.20   	PredCurrGain+244.1372986   	ActualGain+1.00   	PredLongTermGain+3.32
# 506 	CurrClose:250.45   	PredCurrGain+247.6773834   	ActualGain+1.01   	PredLongTermGain+3.36
# 507 	CurrClose:253.79   	PredCurrGain+249.4720917   	ActualGain+1.01   	PredLongTermGain+3.46
# 508 	CurrClose:259.68   	PredCurrGain+250.8882751   	ActualGain+1.02   	PredLongTermGain+3.64
# 509 	CurrClose:259.38   	PredCurrGain+254.2243805   	ActualGain+1.00   	PredLongTermGain+3.63
# 510 	CurrClose:257.79   	PredCurrGain+256.7987976   	ActualGain+0.99   	PredLongTermGain+3.58
# 511 	CurrClose:258.00   	PredCurrGain+257.8698120   	ActualGain+1.00   	PredLongTermGain+3.59
# ...
# 2285 	CurrClose:585.93   	PredCurrGain+581.1213379   	ActualGain+1.02   	PredLongTermGain+8.31
# 2286 	CurrClose:584.77   	PredCurrGain+587.3123779   	ActualGain+1.00   	PredLongTermGain+8.27
# 2287 	CurrClose:585.69   	PredCurrGain+592.8966675   	ActualGain+1.00   	PredLongTermGain+8.30
# 2288 	CurrClose:584.67   	PredCurrGain+595.1065063   	ActualGain+1.00   	PredLongTermGain+8.27
# 2289 	CurrClose:591.49   	PredCurrGain+595.6148071   	ActualGain+1.01   	PredLongTermGain+8.48
# 2290 	CurrClose:590.78   	PredCurrGain+598.0192261   	ActualGain+1.00   	PredLongTermGain+8.46
# 2291 	CurrClose:593.08   	PredCurrGain+599.9949341   	ActualGain+1.00   	PredLongTermGain+8.54
# 2292 	CurrClose:590.76   	PredCurrGain+601.2096558   	ActualGain+1.00   	PredLongTermGain+8.46
# 2293 	CurrClose:578.40   	PredCurrGain+601.2717285   	ActualGain+0.98   	PredLongTermGain+8.06
# 2294 	CurrClose:583.36   	PredCurrGain+594.5245361   	ActualGain+1.01   	PredLongTermGain+8.22
# 2295 	CurrClose:580.04   	PredCurrGain+591.2277832   	ActualGain+0.99   	PredLongTermGain+8.11
# 2296 	CurrClose:586.65   	PredCurrGain+587.8551636   	ActualGain+1.01   	PredLongTermGain+8.32
# 2297 	CurrClose:594.26   	PredCurrGain+590.5221558   	ActualGain+1.01   	PredLongTermGain+8.56
# 2298 	CurrClose:593.06   	PredCurrGain+596.8119507   	ActualGain+1.00   	PredLongTermGain+8.52
# 2299 	CurrClose:590.62   	PredCurrGain+600.4340820   	ActualGain+1.00   	PredLongTermGain+8.45
# 2300 	CurrClose:580.82   	PredCurrGain+602.7439575   	ActualGain+0.98   	PredLongTermGain+8.13
# 2301 	CurrClose:605.11   	PredCurrGain+597.3084717   	ActualGain+1.04   	PredLongTermGain+8.90
# 2302 	CurrClose:598.44   	PredCurrGain+604.8228149   	ActualGain+0.99   	PredLongTermGain+8.67
# 2303 	CurrClose:603.57   	PredCurrGain+608.1571045   	ActualGain+1.01   	PredLongTermGain+8.84
# 2304 	CurrClose:605.19   	PredCurrGain+611.7432861   	ActualGain+1.00   	PredLongTermGain+8.90
# 2305 	CurrClose:603.01   	PredCurrGain+614.0543213   	ActualGain+1.00   	PredLongTermGain+8.82
# 2306 	CurrClose:598.08   	PredCurrGain+614.8557129   	ActualGain+0.99   	PredLongTermGain+8.66
# 2307 	CurrClose:599.02   	PredCurrGain+611.3284302   	ActualGain+1.00   	PredLongTermGain+8.69
# 2308 	CurrClose:593.95   	PredCurrGain+608.7297974   	ActualGain+0.99   	PredLongTermGain+8.53
# 2309 	CurrClose:595.44   	PredCurrGain+606.0236816   	ActualGain+1.00   	PredLongTermGain+8.57
# 2310 	CurrClose:579.55   	PredCurrGain+605.0339966   	ActualGain+0.97   	PredLongTermGain+8.06
# 2311 	CurrClose:573.60   	PredCurrGain+597.4208984   	ActualGain+0.99   	PredLongTermGain+7.87
# 2312 	CurrClose:582.27   	PredCurrGain+589.1256104   	ActualGain+1.02   	PredLongTermGain+8.14
# 2313 	CurrClose:573.14   	PredCurrGain+587.4087524   	ActualGain+0.98   	PredLongTermGain+7.85
# 2314 	CurrClose:574.49   	PredCurrGain+585.0050049   	ActualGain+1.00   	PredLongTermGain+7.90
# 2315 	CurrClose:571.81   	PredCurrGain+582.8336182   	ActualGain+1.00   	PredLongTermGain+7.81
# 2316 	CurrClose:577.94   	PredCurrGain+582.6130371   	ActualGain+1.01   	PredLongTermGain+8.00
# 2317 	CurrClose:577.25   	PredCurrGain+583.6591797   	ActualGain+1.00   	PredLongTermGain+7.98
# 2318 	CurrClose:572.12   	PredCurrGain+586.0817261   	ActualGain+0.99   	PredLongTermGain+7.82
# 2319 	CurrClose:584.56   	PredCurrGain+584.4408569   	ActualGain+1.02   	PredLongTermGain+8.20
# 2320 	CurrClose:584.65   	PredCurrGain+588.1056519   	ActualGain+1.00   	PredLongTermGain+8.21
# 2321 	CurrClose:583.71   	PredCurrGain+592.4891968   	ActualGain+1.00   	PredLongTermGain+8.18
# 2322 	CurrClose:592.70   	PredCurrGain+594.5388184   	ActualGain+1.02   	PredLongTermGain+8.46
# 2323 	CurrClose:597.11   	PredCurrGain+598.6781006   	ActualGain+1.01   	PredLongTermGain+8.60
# 2324 	CurrClose:595.41   	PredCurrGain+604.0480347   	ActualGain+1.00   	PredLongTermGain+8.55
# 2325 	CurrClose:592.42   	PredCurrGain+605.8562622   	ActualGain+0.99   	PredLongTermGain+8.45
# 2326 	CurrClose:592.54   	PredCurrGain+604.7846680   	ActualGain+1.00   	PredLongTermGain+8.45
# 2327 	CurrClose:590.57   	PredCurrGain+603.4285889   	ActualGain+1.00   	PredLongTermGain+8.39
# 2328 	CurrClose:588.12   	PredCurrGain+602.2495728   	ActualGain+1.00   	PredLongTermGain+8.31
# 2329 	CurrClose:583.00   	PredCurrGain+600.1028442   	ActualGain+0.99   	PredLongTermGain+8.15
# 2330 	CurrClose:580.32   	PredCurrGain+596.2145996   	ActualGain+1.00   	PredLongTermGain+8.06
# 2331 	CurrClose:582.36   	PredCurrGain+591.8846436   	ActualGain+1.00   	PredLongTermGain+8.13
# 2332 	CurrClose:588.63   	PredCurrGain+590.5150146   	ActualGain+1.01   	PredLongTermGain+8.33
# 2333 	CurrClose:589.52   	PredCurrGain+592.9918823   	ActualGain+1.00   	PredLongTermGain+8.35
# 2334 	CurrClose:593.14   	PredCurrGain+597.1923828   	ActualGain+1.01   	PredLongTermGain+8.47
# 2335 	CurrClose:597.78   	PredCurrGain+601.3605347   	ActualGain+1.01   	PredLongTermGain+8.62
# 2336 	CurrClose:601.63   	PredCurrGain+605.1287842   	ActualGain+1.01   	PredLongTermGain+8.74
# 2337 	CurrClose:591.97   	PredCurrGain+609.3090210   	ActualGain+0.98   	PredLongTermGain+8.43
# 2338 	CurrClose:593.42   	PredCurrGain+607.6342773   	ActualGain+1.00   	PredLongTermGain+8.47
# 2339 	CurrClose:591.11   	PredCurrGain+604.2473755   	ActualGain+1.00   	PredLongTermGain+8.40
# 2340 	CurrClose:584.90   	PredCurrGain+601.0916748   	ActualGain+0.99   	PredLongTermGain+8.20
# 2341 	CurrClose:581.64   	PredCurrGain+597.7521362   	ActualGain+0.99   	PredLongTermGain+8.10
# 2342 	CurrClose:588.78   	PredCurrGain+592.8190918   	ActualGain+1.01   	PredLongTermGain+8.32
# 2343 	CurrClose:593.29   	PredCurrGain+593.2769775   	ActualGain+1.01   	PredLongTermGain+8.46
# 2344 	CurrClose:597.27   	PredCurrGain+597.6871338   	ActualGain+1.01   	PredLongTermGain+8.59
# 2345 	CurrClose:605.40   	PredCurrGain+602.9178467   	ActualGain+1.01   	PredLongTermGain+8.86
# 2346 	CurrClose:597.27   	PredCurrGain+608.9499512   	ActualGain+0.99   	PredLongTermGain+8.59
# 2347 	CurrClose:591.18   	PredCurrGain+609.9525146   	ActualGain+0.99   	PredLongTermGain+8.39
# 2348 	CurrClose:598.42   	PredCurrGain+606.4225464   	ActualGain+1.01   	PredLongTermGain+8.62
# 2349 	CurrClose:585.25   	PredCurrGain+605.5980835   	ActualGain+0.98   	PredLongTermGain+8.20
# 2350 	CurrClose:587.90   	PredCurrGain+602.0148315   	ActualGain+1.00   	PredLongTermGain+8.28
# 2351 	CurrClose:587.81   	PredCurrGain+598.5451660   	ActualGain+1.00   	PredLongTermGain+8.28
# 2352 	CurrClose:588.41   	PredCurrGain+595.8818970   	ActualGain+1.00   	PredLongTermGain+8.29
# 2353 	CurrClose:579.63   	PredCurrGain+596.1960449   	ActualGain+0.99   	PredLongTermGain+8.02
# 2354 	CurrClose:580.88   	PredCurrGain+593.5925293   	ActualGain+1.00   	PredLongTermGain+8.06
# 2355 	CurrClose:586.25   	PredCurrGain+590.3502808   	ActualGain+1.01   	PredLongTermGain+8.22
# 2356 	CurrClose:587.78   	PredCurrGain+592.8450317   	ActualGain+1.00   	PredLongTermGain+8.27
# 2357 	CurrClose:574.10   	PredCurrGain+596.2788696   	ActualGain+0.98   	PredLongTermGain+7.84
# 2358 	CurrClose:583.74   	PredCurrGain+592.1096191   	ActualGain+1.02   	PredLongTermGain+8.13
# 2359 	CurrClose:570.81   	PredCurrGain+589.2729492   	ActualGain+0.98   	PredLongTermGain+7.73
# 2360 	CurrClose:555.19   	PredCurrGain+585.9780884   	ActualGain+0.97   	PredLongTermGain+7.25
# 2361 	CurrClose:544.75   	PredCurrGain+576.4949951   	ActualGain+0.98   	PredLongTermGain+6.95
# 2362 	CurrClose:548.69   	PredCurrGain+564.9598389   	ActualGain+1.01   	PredLongTermGain+7.06
# 2363 	CurrClose:540.73   	PredCurrGain+559.5547485   	ActualGain+0.99   	PredLongTermGain+6.83
# 2364 	CurrClose:536.92   	PredCurrGain+550.7072144   	ActualGain+0.99   	PredLongTermGain+6.72
# 2365 	CurrClose:522.97   	PredCurrGain+543.4237061   	ActualGain+0.97   	PredLongTermGain+6.33
# 2366 	CurrClose:532.38   	PredCurrGain+538.1918335   	ActualGain+1.02   	PredLongTermGain+6.58
# 2367 	CurrClose:538.03   	PredCurrGain+535.4283447   	ActualGain+1.01   	PredLongTermGain+6.74
# 2368 	CurrClose:542.69   	PredCurrGain+540.0513916   	ActualGain+1.01   	PredLongTermGain+6.87
# 2369 	CurrClose:553.65   	PredCurrGain+547.3468018   	ActualGain+1.02   	PredLongTermGain+7.18
# 2370 	CurrClose:548.90   	PredCurrGain+556.0862427   	ActualGain+0.99   	PredLongTermGain+7.05
# 2371 	CurrClose:549.88   	PredCurrGain+559.6691895   	ActualGain+1.00   	PredLongTermGain+7.07
# 2372 	CurrClose:558.94   	PredCurrGain+560.2883301   	ActualGain+1.02   	PredLongTermGain+7.34
# 2373 	CurrClose:558.45   	PredCurrGain+563.2111816   	ActualGain+1.00   	PredLongTermGain+7.32
# 2374 	CurrClose:560.27   	PredCurrGain+566.7468262   	ActualGain+1.00   	PredLongTermGain+7.38
# 2375 	CurrClose:567.87   	PredCurrGain+567.4441528   	ActualGain+1.01   	PredLongTermGain+7.60
# 2376 	CurrClose:563.77   	PredCurrGain+572.6641846   	ActualGain+0.99   	PredLongTermGain+7.48
# 2377 	CurrClose:564.19   	PredCurrGain+573.1937866   	ActualGain+1.00   	PredLongTermGain+7.49
# 2378 	CurrClose:555.95   	PredCurrGain+572.0068970   	ActualGain+0.99   	PredLongTermGain+7.24
# 2379 	CurrClose:551.69   	PredCurrGain+569.6506348   	ActualGain+0.99   	PredLongTermGain+7.12
# 2380 	CurrClose:551.82   	PredCurrGain+564.4459229   	ActualGain+1.00   	PredLongTermGain+7.12
# 2381 	CurrClose:558.23   	PredCurrGain+561.4973755   	ActualGain+1.01   	PredLongTermGain+7.31
# 2382 	CurrClose:561.29   	PredCurrGain+562.3083496   	ActualGain+1.01   	PredLongTermGain+7.40
# 2383 	CurrClose:558.25   	PredCurrGain+565.5130615   	ActualGain+0.99   	PredLongTermGain+7.31
# 2384 	CurrClose:556.44   	PredCurrGain+566.8324585   	ActualGain+1.00   	PredLongTermGain+7.26
# 2385 	CurrClose:555.19   	PredCurrGain+566.6983032   	ActualGain+1.00   	PredLongTermGain+7.22
# 2386 	CurrClose:546.64   	PredCurrGain+565.3449707   	ActualGain+0.98   	PredLongTermGain+6.97
# 2387 	CurrClose:544.51   	PredCurrGain+560.8453979   	ActualGain+1.00   	PredLongTermGain+6.91
# 2388 	CurrClose:547.20   	PredCurrGain+556.8426514   	ActualGain+1.00   	PredLongTermGain+6.98
# 2389 	CurrClose:543.76   	PredCurrGain+553.9830322   	ActualGain+0.99   	PredLongTermGain+6.89
# 2390 	CurrClose:545.89   	PredCurrGain+551.7794800   	ActualGain+1.00   	PredLongTermGain+6.95
# 2391 	CurrClose:547.48   	PredCurrGain+553.5512695   	ActualGain+1.00   	PredLongTermGain+6.99
# 2392 	CurrClose:549.23   	PredCurrGain+554.7295532   	ActualGain+1.00   	PredLongTermGain+7.04
# 2393 	CurrClose:547.73   	PredCurrGain+556.4047241   	ActualGain+1.00   	PredLongTermGain+7.00
# 2394 	CurrClose:549.08   	PredCurrGain+556.6535645   	ActualGain+1.00   	PredLongTermGain+7.04
# 2395 	CurrClose:539.65   	PredCurrGain+556.5057983   	ActualGain+0.98   	PredLongTermGain+6.77
# 2396 	CurrClose:538.59   	PredCurrGain+553.0341187   	ActualGain+1.00   	PredLongTermGain+6.74
# 2397 	CurrClose:536.97   	PredCurrGain+548.8163452   	ActualGain+1.00   	PredLongTermGain+6.69
# 2398 	CurrClose:542.58   	PredCurrGain+546.2484741   	ActualGain+1.01   	PredLongTermGain+6.85
# 2399 	CurrClose:528.08   	PredCurrGain+546.4686890   	ActualGain+0.97   	PredLongTermGain+6.44
# 2400 	CurrClose:530.73   	PredCurrGain+541.9446411   	ActualGain+1.01   	PredLongTermGain+6.51
# 2401 	CurrClose:536.11   	PredCurrGain+538.8092651   	ActualGain+1.01   	PredLongTermGain+6.66
# 2402 	CurrClose:528.04   	PredCurrGain+538.1311035   	ActualGain+0.98   	PredLongTermGain+6.43
# 2403 	CurrClose:532.11   	PredCurrGain+538.5966797   	ActualGain+1.01   	PredLongTermGain+6.54
# 2404 	CurrClose:521.51   	PredCurrGain+539.2920532   	ActualGain+0.98   	PredLongTermGain+6.25
# 2405 	CurrClose:515.84   	PredCurrGain+535.4884033   	ActualGain+0.99   	PredLongTermGain+6.10
# 2406 	CurrClose:498.16   	PredCurrGain+530.0590820   	ActualGain+0.97   	PredLongTermGain+5.63
# 2407 	CurrClose:506.45   	PredCurrGain+518.4033813   	ActualGain+1.02   	PredLongTermGain+5.84
# 2408 	CurrClose:514.62   	PredCurrGain+512.2969360   	ActualGain+1.02   	PredLongTermGain+6.05
# 2409 	CurrClose:520.04   	PredCurrGain+515.3010254   	ActualGain+1.01   	PredLongTermGain+6.19
# 2410 	CurrClose:532.30   	PredCurrGain+519.7704468   	ActualGain+1.02   	PredLongTermGain+6.52
# 2411 	CurrClose:538.77   	PredCurrGain+528.8582153   	ActualGain+1.01   	PredLongTermGain+6.70
# 2412 	CurrClose:536.93   	PredCurrGain+539.7357178   	ActualGain+1.00   	PredLongTermGain+6.65
# 2413 	CurrClose:541.52   	PredCurrGain+545.3027954   	ActualGain+1.01   	PredLongTermGain+6.78
# 2414 	CurrClose:537.31   	PredCurrGain+548.2319946   	ActualGain+0.99   	PredLongTermGain+6.66
# 2415 	CurrClose:535.28   	PredCurrGain+548.5483398   	ActualGain+1.00   	PredLongTermGain+6.60
# 2416 	CurrClose:530.66   	PredCurrGain+545.8269653   	ActualGain+0.99   	PredLongTermGain+6.47
# 2417 	CurrClose:529.55   	PredCurrGain+542.8002930   	ActualGain+1.00   	PredLongTermGain+6.44
# 2418 	CurrClose:519.46   	PredCurrGain+539.6730347   	ActualGain+0.98   	PredLongTermGain+6.17
# 2419 	CurrClose:506.64   	PredCurrGain+532.9366455   	ActualGain+0.98   	PredLongTermGain+5.82
# 2420 	CurrClose:505.15   	PredCurrGain+523.5543823   	ActualGain+1.00   	PredLongTermGain+5.78
# 2421 	CurrClose:506.91   	PredCurrGain+516.3644409   	ActualGain+1.00   	PredLongTermGain+5.83
# 2422 	CurrClose:500.72   	PredCurrGain+510.6583557   	ActualGain+0.99   	PredLongTermGain+5.67
# 2423 	CurrClose:497.06   	PredCurrGain+508.9243774   	ActualGain+0.99   	PredLongTermGain+5.58
# 2424 	CurrClose:501.80   	PredCurrGain+504.7986145   	ActualGain+1.01   	PredLongTermGain+5.70
# 2425 	CurrClose:505.93   	PredCurrGain+506.3847961   	ActualGain+1.01   	PredLongTermGain+5.80
# 2426 	CurrClose:504.01   	PredCurrGain+508.5603333   	ActualGain+1.00   	PredLongTermGain+5.75
# 2427 	CurrClose:510.46   	PredCurrGain+511.2341309   	ActualGain+1.01   	PredLongTermGain+5.92
# 2428 	CurrClose:509.94   	PredCurrGain+513.5338135   	ActualGain+1.00   	PredLongTermGain+5.90
# 2429 	CurrClose:520.39   	PredCurrGain+517.0455322   	ActualGain+1.02   	PredLongTermGain+6.18
# 2430 	CurrClose:537.30   	PredCurrGain+521.3307495   	ActualGain+1.03   	PredLongTermGain+6.63
# 2431 	CurrClose:541.95   	PredCurrGain+531.9968872   	ActualGain+1.01   	PredLongTermGain+6.76
# 2432 	CurrClose:536.72   	PredCurrGain+543.0092773   	ActualGain+0.99   	PredLongTermGain+6.61
# 2433 	CurrClose:521.19   	PredCurrGain+546.3959961   	ActualGain+0.97   	PredLongTermGain+6.18
# 2434 	CurrClose:512.43   	PredCurrGain+539.8270874   	ActualGain+0.98   	PredLongTermGain+5.95
# 2435 	CurrClose:513.23   	PredCurrGain+530.7863159   	ActualGain+1.00   	PredLongTermGain+5.97
# 2436 	CurrClose:537.55   	PredCurrGain+521.6831055   	ActualGain+1.05   	PredLongTermGain+6.60
# 2437 	CurrClose:532.20   	PredCurrGain+528.3562622   	ActualGain+0.99   	PredLongTermGain+6.46
# 2438 	CurrClose:533.30   	PredCurrGain+533.7651367   	ActualGain+1.00   	PredLongTermGain+6.49
# 2439 	CurrClose:526.10   	PredCurrGain+537.5484009   	ActualGain+0.99   	PredLongTermGain+6.29
# 2440 	CurrClose:529.83   	PredCurrGain+537.9409790   	ActualGain+1.01   	PredLongTermGain+6.39
# 2441 	CurrClose:533.88   	PredCurrGain+537.2695312   	ActualGain+1.01   	PredLongTermGain+6.50
# 2442 	CurrClose:529.28   	PredCurrGain+539.3424072   	ActualGain+0.99   	PredLongTermGain+6.37
# 2443 	CurrClose:540.16   	PredCurrGain+538.6314697   	ActualGain+1.02   	PredLongTermGain+6.67
# 2444 	CurrClose:538.00   	PredCurrGain+541.3640137   	ActualGain+1.00   	PredLongTermGain+6.61
# 2445 	CurrClose:546.01   	PredCurrGain+544.4877930   	ActualGain+1.01   	PredLongTermGain+6.83
# 2446 	CurrClose:551.16   	PredCurrGain+548.4575195   	ActualGain+1.01   	PredLongTermGain+6.97
# 2447 	CurrClose:545.01   	PredCurrGain+554.2985840   	ActualGain+0.99   	PredLongTermGain+6.80
# 2448 	CurrClose:542.65   	PredCurrGain+555.8100586   	ActualGain+1.00   	PredLongTermGain+6.73
# 2449 	CurrClose:546.45   	PredCurrGain+553.5703125   	ActualGain+1.01   	PredLongTermGain+6.84
# 2450 	CurrClose:541.80   	PredCurrGain+552.6654663   	ActualGain+0.99   	PredLongTermGain+6.71
# 2451 	CurrClose:535.00   	PredCurrGain+551.3659058   	ActualGain+0.99   	PredLongTermGain+6.52
#
#
#
# Final gain comparasion:	 [6.51839414] rather than Long-Term-Gain [4.12395812] , Trading times 2451
# array([6.51839414])

# %%
SumRes(predTest,yTest,3.5,1)
# Out:
# 1 	CurrClose:692.84   	PredCurrGain+662.8400879   	ActualGain+0.99   	PredLongTermGain+0.97
# 2 	CurrClose:695.35   	PredCurrGain+694.4013672   	ActualGain+1.00   	PredLongTermGain+0.98
# 3 	CurrClose:695.10   	PredCurrGain+707.7055054   	ActualGain+1.00   	PredLongTermGain+0.98
# 4 	CurrClose:674.73   	PredCurrGain+713.2467651   	ActualGain+0.97   	PredLongTermGain+0.88
# 5 	CurrClose:654.77   	PredCurrGain+703.0169067   	ActualGain+0.97   	PredLongTermGain+0.79
# 6 	CurrClose:658.27   	PredCurrGain+684.6050415   	ActualGain+1.01   	PredLongTermGain+0.80
# 7 	CurrClose:659.66   	PredCurrGain+671.5267334   	ActualGain+1.00   	PredLongTermGain+0.81
# 8 	CurrClose:661.43   	PredCurrGain+667.6939697   	ActualGain+1.00   	PredLongTermGain+0.81
# 9 	CurrClose:664.56   	PredCurrGain+667.5033569   	ActualGain+1.00   	PredLongTermGain+0.83
# 10 	CurrClose:657.50   	PredCurrGain+669.1322632   	ActualGain+0.99   	PredLongTermGain+0.80
# 11 	CurrClose:664.72   	PredCurrGain+670.6986694   	ActualGain+1.01   	PredLongTermGain+0.83
# 12 	CurrClose:661.28   	PredCurrGain+672.8354492   	ActualGain+0.99   	PredLongTermGain+0.81
# 13 	CurrClose:673.29   	PredCurrGain+674.7821045   	ActualGain+1.02   	PredLongTermGain+0.86
# 14 	CurrClose:670.15   	PredCurrGain+680.6593018   	ActualGain+1.00   	PredLongTermGain+0.85
# 15 	CurrClose:664.39   	PredCurrGain+682.4504395   	ActualGain+0.99   	PredLongTermGain+0.82
# 16 	CurrClose:663.14   	PredCurrGain+680.0564575   	ActualGain+1.00   	PredLongTermGain+0.82
# 17 	CurrClose:690.30   	PredCurrGain+678.6160278   	ActualGain+1.04   	PredLongTermGain+0.94
# 18 	CurrClose:691.47   	PredCurrGain+694.8477173   	ActualGain+1.00   	PredLongTermGain+0.94
# 19 	CurrClose:686.51   	PredCurrGain+702.0707397   	ActualGain+0.99   	PredLongTermGain+0.92
# 20 	CurrClose:689.37   	PredCurrGain+703.3053589   	ActualGain+1.00   	PredLongTermGain+0.93
# 21 	CurrClose:694.11   	PredCurrGain+702.8775635   	ActualGain+1.01   	PredLongTermGain+0.95
# 22 	CurrClose:688.73   	PredCurrGain+703.8665161   	ActualGain+0.99   	PredLongTermGain+0.93
# 23 	CurrClose:694.04   	PredCurrGain+703.7635498   	ActualGain+1.01   	PredLongTermGain+0.95
# 24 	CurrClose:679.48   	PredCurrGain+705.1322021   	ActualGain+0.98   	PredLongTermGain+0.88
# 25 	CurrClose:644.03   	PredCurrGain+700.2135010   	ActualGain+0.95   	PredLongTermGain+0.72
# 26 	CurrClose:618.11   	PredCurrGain+679.6089478   	ActualGain+0.96   	PredLongTermGain+0.62
# 27 	CurrClose:612.47   	PredCurrGain+641.8162842   	ActualGain+0.99   	PredLongTermGain+0.60
# 28 	CurrClose:659.74   	PredCurrGain+634.1810303   	ActualGain+1.08   	PredLongTermGain+0.76
# 29 	CurrClose:667.96   	PredCurrGain+647.9135132   	ActualGain+1.01   	PredLongTermGain+0.80
# 30 	CurrClose:659.69   	PredCurrGain+667.4370728   	ActualGain+0.99   	PredLongTermGain+0.76
# 31 	CurrClose:647.82   	PredCurrGain+674.8119507   	ActualGain+0.98   	PredLongTermGain+0.71
# 32 	CurrClose:629.56   	PredCurrGain+671.8690796   	ActualGain+0.97   	PredLongTermGain+0.64
# 33 	CurrClose:644.91   	PredCurrGain+656.7796631   	ActualGain+1.02   	PredLongTermGain+0.70
# 34 	CurrClose:637.05   	PredCurrGain+653.2009888   	ActualGain+0.99   	PredLongTermGain+0.67
# 35 	CurrClose:628.96   	PredCurrGain+652.7219238   	ActualGain+0.99   	PredLongTermGain+0.64
# 36 	CurrClose:643.88   	PredCurrGain+645.8065186   	ActualGain+1.02   	PredLongTermGain+0.69
# 37 	CurrClose:643.41   	PredCurrGain+649.2518921   	ActualGain+1.00   	PredLongTermGain+0.69
# 38 	CurrClose:651.08   	PredCurrGain+655.6481934   	ActualGain+1.01   	PredLongTermGain+0.72
# 39 	CurrClose:655.30   	PredCurrGain+659.7232056   	ActualGain+1.01   	PredLongTermGain+0.74
# 40 	CurrClose:652.47   	PredCurrGain+663.8884277   	ActualGain+1.00   	PredLongTermGain+0.72
# 41 	CurrClose:665.07   	PredCurrGain+665.9511108   	ActualGain+1.02   	PredLongTermGain+0.77
# 42 	CurrClose:665.52   	PredCurrGain+671.4030151   	ActualGain+1.00   	PredLongTermGain+0.77
# 43 	CurrClose:671.67   	PredCurrGain+676.3923340   	ActualGain+1.01   	PredLongTermGain+0.80
# 44 	CurrClose:660.92   	PredCurrGain+681.8706665   	ActualGain+0.98   	PredLongTermGain+0.75
# 45 	CurrClose:666.98   	PredCurrGain+678.9940796   	ActualGain+1.01   	PredLongTermGain+0.78
# 46 	CurrClose:653.20   	PredCurrGain+678.1430054   	ActualGain+0.98   	PredLongTermGain+0.72
# 47 	CurrClose:653.29   	PredCurrGain+670.0883179   	ActualGain+1.00   	PredLongTermGain+0.72
# 48 	CurrClose:654.91   	PredCurrGain+666.8187256   	ActualGain+1.00   	PredLongTermGain+0.73
# 49 	CurrClose:640.15   	PredCurrGain+663.6166382   	ActualGain+0.98   	PredLongTermGain+0.67
# 50 	CurrClose:624.25   	PredCurrGain+660.3043213   	ActualGain+0.98   	PredLongTermGain+0.61
# 51 	CurrClose:622.61   	PredCurrGain+648.1755981   	ActualGain+1.00   	PredLongTermGain+0.61
# 52 	CurrClose:638.37   	PredCurrGain+639.6025391   	ActualGain+1.03   	PredLongTermGain+0.66
# 53 	CurrClose:642.00   	PredCurrGain+642.4196167   	ActualGain+1.01   	PredLongTermGain+0.67
# 54 	CurrClose:656.99   	PredCurrGain+647.3508301   	ActualGain+1.02   	PredLongTermGain+0.73
# 55 	CurrClose:671.68   	PredCurrGain+655.3654785   	ActualGain+1.02   	PredLongTermGain+0.79
# 56 	CurrClose:671.64   	PredCurrGain+671.0442505   	ActualGain+1.00   	PredLongTermGain+0.79
# 57 	CurrClose:670.00   	PredCurrGain+681.2316284   	ActualGain+1.00   	PredLongTermGain+0.78
# 58 	CurrClose:667.00   	PredCurrGain+684.8978882   	ActualGain+1.00   	PredLongTermGain+0.77
# 59 	CurrClose:671.24   	PredCurrGain+682.4119263   	ActualGain+1.01   	PredLongTermGain+0.79
# 60 	CurrClose:676.43   	PredCurrGain+682.3844604   	ActualGain+1.01   	PredLongTermGain+0.81
# 61 	CurrClose:683.17   	PredCurrGain+684.5913086   	ActualGain+1.01   	PredLongTermGain+0.83
# 62 	CurrClose:680.41   	PredCurrGain+689.6860962   	ActualGain+1.00   	PredLongTermGain+0.82
# 63 	CurrClose:693.02   	PredCurrGain+694.0006714   	ActualGain+1.02   	PredLongTermGain+0.88
# 64 	CurrClose:695.32   	PredCurrGain+699.9226685   	ActualGain+1.00   	PredLongTermGain+0.89
# 65 	CurrClose:699.95   	PredCurrGain+705.3566895   	ActualGain+1.01   	PredLongTermGain+0.91
# 66 	CurrClose:680.00   	PredCurrGain+709.3944702   	ActualGain+0.97   	PredLongTermGain+0.82
# 67 	CurrClose:671.80   	PredCurrGain+703.5302124   	ActualGain+0.99   	PredLongTermGain+0.78
# 68 	CurrClose:681.14   	PredCurrGain+694.8097534   	ActualGain+1.01   	PredLongTermGain+0.82
# 69 	CurrClose:719.33   	PredCurrGain+691.4761963   	ActualGain+1.06   	PredLongTermGain+0.98
# 70 	CurrClose:731.12   	PredCurrGain+723.3877563   	ActualGain+1.02   	PredLongTermGain+1.04
# 71 	CurrClose:732.82   	PredCurrGain+738.3334351   	ActualGain+1.00   	PredLongTermGain+1.05
# 72 	CurrClose:736.92   	PredCurrGain+746.0290527   	ActualGain+1.01   	PredLongTermGain+1.07
# 73 	CurrClose:744.85   	PredCurrGain+750.1927490   	ActualGain+1.01   	PredLongTermGain+1.11
# 74 	CurrClose:737.39   	PredCurrGain+755.3994141   	ActualGain+0.99   	PredLongTermGain+1.07
# 75 	CurrClose:747.74   	PredCurrGain+756.5595703   	ActualGain+1.01   	PredLongTermGain+1.12
# 76 	CurrClose:748.82   	PredCurrGain+756.6481934   	ActualGain+1.00   	PredLongTermGain+1.13
# 77 	CurrClose:755.31   	PredCurrGain+759.9735718   	ActualGain+1.01   	PredLongTermGain+1.16
# 78 	CurrClose:760.67   	PredCurrGain+765.7392578   	ActualGain+1.01   	PredLongTermGain+1.19
# 79 	CurrClose:761.60   	PredCurrGain+772.8519287   	ActualGain+1.00   	PredLongTermGain+1.19
# 80 	CurrClose:754.77   	PredCurrGain+775.5890503   	ActualGain+0.99   	PredLongTermGain+1.16
# 81 	CurrClose:758.26   	PredCurrGain+773.7760620   	ActualGain+1.00   	PredLongTermGain+1.17
# 82 	CurrClose:765.25   	PredCurrGain+772.2814331   	ActualGain+1.01   	PredLongTermGain+1.21
# 83 	CurrClose:756.53   	PredCurrGain+776.9276123   	ActualGain+0.99   	PredLongTermGain+1.16
# 84 	CurrClose:740.07   	PredCurrGain+776.2615356   	ActualGain+0.98   	PredLongTermGain+1.08
# 85 	CurrClose:750.42   	PredCurrGain+767.2594604   	ActualGain+1.01   	PredLongTermGain+1.13
# 86 	CurrClose:745.98   	PredCurrGain+762.1376953   	ActualGain+0.99   	PredLongTermGain+1.11
# 87 	CurrClose:760.01   	PredCurrGain+762.9729004   	ActualGain+1.02   	PredLongTermGain+1.18
# 88 	CurrClose:759.94   	PredCurrGain+768.1130981   	ActualGain+1.00   	PredLongTermGain+1.18
# 89 	CurrClose:777.00   	PredCurrGain+774.2047729   	ActualGain+1.02   	PredLongTermGain+1.27
# 90 	CurrClose:776.70   	PredCurrGain+784.7462158   	ActualGain+1.00   	PredLongTermGain+1.27
# 91 	CurrClose:769.63   	PredCurrGain+792.8308716   	ActualGain+0.99   	PredLongTermGain+1.23
# 92 	CurrClose:769.26   	PredCurrGain+790.1127930   	ActualGain+1.00   	PredLongTermGain+1.23
# 93 	CurrClose:771.97   	PredCurrGain+788.9467773   	ActualGain+1.00   	PredLongTermGain+1.24
# 94 	CurrClose:762.85   	PredCurrGain+788.5673828   	ActualGain+0.99   	PredLongTermGain+1.19
# 95 	CurrClose:783.79   	PredCurrGain+785.5274048   	ActualGain+1.03   	PredLongTermGain+1.30
# 96 	CurrClose:777.85   	PredCurrGain+790.1573486   	ActualGain+0.99   	PredLongTermGain+1.27
# 97 	CurrClose:768.20   	PredCurrGain+796.4614868   	ActualGain+0.99   	PredLongTermGain+1.21
# 98 	CurrClose:779.21   	PredCurrGain+793.4683838   	ActualGain+1.01   	PredLongTermGain+1.27
# 99 	CurrClose:772.99   	PredCurrGain+792.8209839   	ActualGain+0.99   	PredLongTermGain+1.24
# 100 	CurrClose:775.14   	PredCurrGain+792.5812988   	ActualGain+1.00   	PredLongTermGain+1.25
# 101 	CurrClose:762.55   	PredCurrGain+790.0683594   	ActualGain+0.98   	PredLongTermGain+1.18
# 102 	CurrClose:760.04   	PredCurrGain+784.6516113   	ActualGain+1.00   	PredLongTermGain+1.17
# 103 	CurrClose:750.42   	PredCurrGain+780.1900024   	ActualGain+0.99   	PredLongTermGain+1.12
# 104 	CurrClose:762.54   	PredCurrGain+772.1645508   	ActualGain+1.02   	PredLongTermGain+1.18
# 105 	CurrClose:760.09   	PredCurrGain+770.2977295   	ActualGain+1.00   	PredLongTermGain+1.16
# 106 	CurrClose:776.59   	PredCurrGain+776.8118286   	ActualGain+1.02   	PredLongTermGain+1.25
# 107 	CurrClose:769.83   	PredCurrGain+784.7048950   	ActualGain+0.99   	PredLongTermGain+1.22
# 108 	CurrClose:756.85   	PredCurrGain+791.0550537   	ActualGain+0.98   	PredLongTermGain+1.14
# 109 	CurrClose:760.80   	PredCurrGain+785.4390869   	ActualGain+1.01   	PredLongTermGain+1.16
# 110 	CurrClose:767.13   	PredCurrGain+781.4065552   	ActualGain+1.01   	PredLongTermGain+1.20
# 111 	CurrClose:768.51   	PredCurrGain+782.4234009   	ActualGain+1.00   	PredLongTermGain+1.21
# 112 	CurrClose:765.84   	PredCurrGain+783.8465576   	ActualGain+1.00   	PredLongTermGain+1.19
# 113 	CurrClose:782.24   	PredCurrGain+784.7405396   	ActualGain+1.02   	PredLongTermGain+1.28
# 114 	CurrClose:793.96   	PredCurrGain+790.8100586   	ActualGain+1.01   	PredLongTermGain+1.35
# 115 	CurrClose:790.30   	PredCurrGain+803.4881592   	ActualGain+1.00   	PredLongTermGain+1.33
# 116 	CurrClose:778.01   	PredCurrGain+809.3594971   	ActualGain+0.98   	PredLongTermGain+1.25
# 117 	CurrClose:759.44   	PredCurrGain+804.9499512   	ActualGain+0.98   	PredLongTermGain+1.15
# 118 	CurrClose:761.53   	PredCurrGain+785.8723755   	ActualGain+1.00   	PredLongTermGain+1.16
# 119 	CurrClose:759.33   	PredCurrGain+779.6893921   	ActualGain+1.00   	PredLongTermGain+1.15
# 120 	CurrClose:741.00   	PredCurrGain+773.9432373   	ActualGain+0.98   	PredLongTermGain+1.05
# 121 	CurrClose:730.91   	PredCurrGain+764.0798950   	ActualGain+0.99   	PredLongTermGain+1.00
# 122 	CurrClose:733.07   	PredCurrGain+756.7144775   	ActualGain+1.00   	PredLongTermGain+1.01
# 123 	CurrClose:745.34   	PredCurrGain+749.2208862   	ActualGain+1.02   	PredLongTermGain+1.07
# 124 	CurrClose:719.57   	PredCurrGain+754.6929321   	ActualGain+0.97   	PredLongTermGain+0.94
# 125 	CurrClose:731.39   	PredCurrGain+751.2174072   	ActualGain+1.02   	PredLongTermGain+1.00
# 126 	CurrClose:710.49   	PredCurrGain+745.7133179   	ActualGain+0.97   	PredLongTermGain+0.90
# 127 	CurrClose:719.08   	PredCurrGain+734.0928345   	ActualGain+1.01   	PredLongTermGain+0.93
# 128 	CurrClose:718.56   	PredCurrGain+733.5264893   	ActualGain+1.00   	PredLongTermGain+0.93
# 129 	CurrClose:726.67   	PredCurrGain+728.3366699   	ActualGain+1.01   	PredLongTermGain+0.97
# 130 	CurrClose:745.46   	PredCurrGain+735.3358154   	ActualGain+1.03   	PredLongTermGain+1.06
# 131 	CurrClose:733.62   	PredCurrGain+752.2426758   	ActualGain+0.98   	PredLongTermGain+1.00
# 132 	CurrClose:733.79   	PredCurrGain+757.1640015   	ActualGain+1.00   	PredLongTermGain+1.00
# 133 	CurrClose:717.58   	PredCurrGain+754.9395752   	ActualGain+0.98   	PredLongTermGain+0.92
# 134 	CurrClose:748.30   	PredCurrGain+746.4738159   	ActualGain+1.04   	PredLongTermGain+1.06
# 135 	CurrClose:761.35   	PredCurrGain+753.3392944   	ActualGain+1.02   	PredLongTermGain+1.12
# 136 	CurrClose:770.77   	PredCurrGain+765.1439209   	ActualGain+1.01   	PredLongTermGain+1.17
# 137 	CurrClose:780.91   	PredCurrGain+779.4941406   	ActualGain+1.01   	PredLongTermGain+1.23
# 138 	CurrClose:749.38   	PredCurrGain+798.7880859   	ActualGain+0.96   	PredLongTermGain+1.05
# 139 	CurrClose:730.03   	PredCurrGain+788.8237305   	ActualGain+0.97   	PredLongTermGain+0.96
# 140 	CurrClose:703.76   	PredCurrGain+765.2054443   	ActualGain+0.96   	PredLongTermGain+0.84
# 141 	CurrClose:704.16   	PredCurrGain+738.9542236   	ActualGain+1.00   	PredLongTermGain+0.84
# 142 	CurrClose:701.02   	PredCurrGain+717.2139282   	ActualGain+1.00   	PredLongTermGain+0.83
# 143 	CurrClose:706.85   	PredCurrGain+711.7504272   	ActualGain+1.01   	PredLongTermGain+0.85
# 144 	CurrClose:706.36   	PredCurrGain+718.5464478   	ActualGain+1.00   	PredLongTermGain+0.85
# 145 	CurrClose:706.89   	PredCurrGain+717.7908936   	ActualGain+1.00   	PredLongTermGain+0.85
# 146 	CurrClose:717.64   	PredCurrGain+722.1270752   	ActualGain+1.02   	PredLongTermGain+0.89
# 147 	CurrClose:731.97   	PredCurrGain+729.7836304   	ActualGain+1.02   	PredLongTermGain+0.96
# 148 	CurrClose:717.51   	PredCurrGain+739.7694702   	ActualGain+0.98   	PredLongTermGain+0.89
# 149 	CurrClose:722.11   	PredCurrGain+741.9547119   	ActualGain+1.01   	PredLongTermGain+0.91
# 150 	CurrClose:729.05   	PredCurrGain+739.0230713   	ActualGain+1.01   	PredLongTermGain+0.94
# 151 	CurrClose:717.29   	PredCurrGain+742.8818359   	ActualGain+0.98   	PredLongTermGain+0.89
# 152 	CurrClose:720.90   	PredCurrGain+739.8048706   	ActualGain+1.01   	PredLongTermGain+0.90
# 153 	CurrClose:729.12   	PredCurrGain+733.4057007   	ActualGain+1.01   	PredLongTermGain+0.94
# 154 	CurrClose:724.86   	PredCurrGain+736.3397217   	ActualGain+0.99   	PredLongTermGain+0.92
# 155 	CurrClose:717.22   	PredCurrGain+740.8164673   	ActualGain+0.99   	PredLongTermGain+0.89
# 156 	CurrClose:742.17   	PredCurrGain+738.4132080   	ActualGain+1.03   	PredLongTermGain+1.00
# 157 	CurrClose:739.48   	PredCurrGain+744.0404053   	ActualGain+1.00   	PredLongTermGain+0.98
# 158 	CurrClose:731.59   	PredCurrGain+751.7722778   	ActualGain+0.99   	PredLongTermGain+0.95
# 159 	CurrClose:730.22   	PredCurrGain+752.1189575   	ActualGain+1.00   	PredLongTermGain+0.94
# 160 	CurrClose:712.80   	PredCurrGain+749.2120361   	ActualGain+0.98   	PredLongTermGain+0.86
# 161 	CurrClose:713.53   	PredCurrGain+737.9783325   	ActualGain+1.00   	PredLongTermGain+0.86
# 162 	CurrClose:725.41   	PredCurrGain+729.9385376   	ActualGain+1.02   	PredLongTermGain+0.91
# 163 	CurrClose:732.17   	PredCurrGain+732.1110840   	ActualGain+1.01   	PredLongTermGain+0.94
# 164 	CurrClose:744.87   	PredCurrGain+740.0330200   	ActualGain+1.02   	PredLongTermGain+1.00
# 165 	CurrClose:750.24   	PredCurrGain+751.9500122   	ActualGain+1.01   	PredLongTermGain+1.03
# 166 	CurrClose:750.57   	PredCurrGain+761.6820679   	ActualGain+1.00   	PredLongTermGain+1.03
# 167 	CurrClose:757.36   	PredCurrGain+765.5067749   	ActualGain+1.01   	PredLongTermGain+1.06
# 168 	CurrClose:758.48   	PredCurrGain+769.4700928   	ActualGain+1.00   	PredLongTermGain+1.07
# 169 	CurrClose:755.41   	PredCurrGain+774.3142090   	ActualGain+1.00   	PredLongTermGain+1.05
# 170 	CurrClose:762.16   	PredCurrGain+774.4047852   	ActualGain+1.01   	PredLongTermGain+1.08
# 171 	CurrClose:760.05   	PredCurrGain+774.8460083   	ActualGain+1.00   	PredLongTermGain+1.07
# 172 	CurrClose:757.56   	PredCurrGain+776.2463989   	ActualGain+1.00   	PredLongTermGain+1.06
# 173 	CurrClose:754.84   	PredCurrGain+776.5554199   	ActualGain+1.00   	PredLongTermGain+1.05
# 174 	CurrClose:753.28   	PredCurrGain+772.5347290   	ActualGain+1.00   	PredLongTermGain+1.04
# 175 	CurrClose:765.89   	PredCurrGain+771.2616577   	ActualGain+1.02   	PredLongTermGain+1.10
# 176 	CurrClose:768.34   	PredCurrGain+773.6439209   	ActualGain+1.00   	PredLongTermGain+1.11
# 177 	CurrClose:762.90   	PredCurrGain+782.0458984   	ActualGain+0.99   	PredLongTermGain+1.09
# 178 	CurrClose:769.67   	PredCurrGain+782.5518799   	ActualGain+1.01   	PredLongTermGain+1.12
# 179 	CurrClose:765.12   	PredCurrGain+782.0098267   	ActualGain+0.99   	PredLongTermGain+1.10
# 180 	CurrClose:758.57   	PredCurrGain+783.4669189   	ActualGain+0.99   	PredLongTermGain+1.06
# 181 	CurrClose:768.07   	PredCurrGain+779.0101318   	ActualGain+1.01   	PredLongTermGain+1.11
# 182 	CurrClose:760.12   	PredCurrGain+779.5004272   	ActualGain+0.99   	PredLongTermGain+1.07
# 183 	CurrClose:759.47   	PredCurrGain+779.5214844   	ActualGain+1.00   	PredLongTermGain+1.07
# 184 	CurrClose:757.54   	PredCurrGain+779.0679321   	ActualGain+1.00   	PredLongTermGain+1.06
# 185 	CurrClose:764.32   	PredCurrGain+778.6510010   	ActualGain+1.01   	PredLongTermGain+1.09
# 186 	CurrClose:771.91   	PredCurrGain+777.9912109   	ActualGain+1.01   	PredLongTermGain+1.13
# 187 	CurrClose:775.39   	PredCurrGain+784.2933960   	ActualGain+1.00   	PredLongTermGain+1.15
# 188 	CurrClose:780.00   	PredCurrGain+790.9235229   	ActualGain+1.01   	PredLongTermGain+1.17
# 189 	CurrClose:787.68   	PredCurrGain+795.1754761   	ActualGain+1.01   	PredLongTermGain+1.21
# 190 	CurrClose:776.25   	PredCurrGain+800.2906494   	ActualGain+0.99   	PredLongTermGain+1.15
# 191 	CurrClose:774.92   	PredCurrGain+799.9918823   	ActualGain+1.00   	PredLongTermGain+1.14
# 192 	CurrClose:780.00   	PredCurrGain+796.5133057   	ActualGain+1.01   	PredLongTermGain+1.17
# 193 	CurrClose:737.77   	PredCurrGain+795.0465088   	ActualGain+0.95   	PredLongTermGain+0.95
# 194 	CurrClose:742.21   	PredCurrGain+769.9370117   	ActualGain+1.01   	PredLongTermGain+0.97
# 195 	CurrClose:725.37   	PredCurrGain+758.8387451   	ActualGain+0.98   	PredLongTermGain+0.89
# 196 	CurrClose:721.46   	PredCurrGain+749.9196167   	ActualGain+0.99   	PredLongTermGain+0.87
# 197 	CurrClose:705.06   	PredCurrGain+739.6777344   	ActualGain+0.98   	PredLongTermGain+0.80
# 198 	CurrClose:707.88   	PredCurrGain+731.5996704   	ActualGain+1.00   	PredLongTermGain+0.82
# 199 	CurrClose:714.41   	PredCurrGain+725.2089233   	ActualGain+1.01   	PredLongTermGain+0.84
# 200 	CurrClose:708.44   	PredCurrGain+726.4445190   	ActualGain+0.99   	PredLongTermGain+0.82
# 201 	CurrClose:711.37   	PredCurrGain+726.4140625   	ActualGain+1.00   	PredLongTermGain+0.83
# 202 	CurrClose:714.71   	PredCurrGain+726.2883301   	ActualGain+1.00   	PredLongTermGain+0.84
# 203 	CurrClose:725.18   	PredCurrGain+729.2176514   	ActualGain+1.01   	PredLongTermGain+0.89
# 204 	CurrClose:729.13   	PredCurrGain+733.8698730   	ActualGain+1.01   	PredLongTermGain+0.90
# 205 	CurrClose:739.38   	PredCurrGain+741.5341187   	ActualGain+1.01   	PredLongTermGain+0.95
# 206 	CurrClose:730.55   	PredCurrGain+750.1932373   	ActualGain+0.99   	PredLongTermGain+0.91
# 207 	CurrClose:728.07   	PredCurrGain+751.9963379   	ActualGain+1.00   	PredLongTermGain+0.90
# 208 	CurrClose:724.83   	PredCurrGain+749.0950317   	ActualGain+1.00   	PredLongTermGain+0.88
# 209 	CurrClose:730.30   	PredCurrGain+745.0049438   	ActualGain+1.01   	PredLongTermGain+0.91
# 210 	CurrClose:720.19   	PredCurrGain+743.3065186   	ActualGain+0.99   	PredLongTermGain+0.86
# 211 	CurrClose:721.78   	PredCurrGain+741.2689819   	ActualGain+1.00   	PredLongTermGain+0.87
# 212 	CurrClose:715.31   	PredCurrGain+737.5952148   	ActualGain+0.99   	PredLongTermGain+0.84
# 213 	CurrClose:721.71   	PredCurrGain+733.1555176   	ActualGain+1.01   	PredLongTermGain+0.87
# 214 	CurrClose:717.25   	PredCurrGain+734.0723877   	ActualGain+0.99   	PredLongTermGain+0.85
# 215 	CurrClose:733.03   	PredCurrGain+734.4032593   	ActualGain+1.02   	PredLongTermGain+0.91
# 216 	CurrClose:738.10   	PredCurrGain+739.7413330   	ActualGain+1.01   	PredLongTermGain+0.94
# 217 	CurrClose:736.93   	PredCurrGain+748.3865356   	ActualGain+1.00   	PredLongTermGain+0.93
# 218 	CurrClose:747.60   	PredCurrGain+752.4867554   	ActualGain+1.01   	PredLongTermGain+0.98
# 219 	CurrClose:748.85   	PredCurrGain+757.7072144   	ActualGain+1.00   	PredLongTermGain+0.98
# 220 	CurrClose:748.46   	PredCurrGain+763.3445435   	ActualGain+1.00   	PredLongTermGain+0.98
# 221 	CurrClose:744.27   	PredCurrGain+765.1735840   	ActualGain+0.99   	PredLongTermGain+0.96
# 222 	CurrClose:735.86   	PredCurrGain+762.2285156   	ActualGain+0.99   	PredLongTermGain+0.93
# 223 	CurrClose:730.06   	PredCurrGain+756.8273926   	ActualGain+0.99   	PredLongTermGain+0.90
# 224 	CurrClose:731.09   	PredCurrGain+751.1361084   	ActualGain+1.00   	PredLongTermGain+0.90
# 225 	CurrClose:742.93   	PredCurrGain+748.5781250   	ActualGain+1.02   	PredLongTermGain+0.96
# 226 	CurrClose:742.52   	PredCurrGain+752.8386841   	ActualGain+1.00   	PredLongTermGain+0.95
# 227 	CurrClose:733.19   	PredCurrGain+755.3990479   	ActualGain+0.99   	PredLongTermGain+0.91
# 228 	CurrClose:731.88   	PredCurrGain+752.8155518   	ActualGain+1.00   	PredLongTermGain+0.91
# 229 	CurrClose:733.25   	PredCurrGain+750.2514648   	ActualGain+1.00   	PredLongTermGain+0.91
# 230 	CurrClose:732.19   	PredCurrGain+748.3207397   	ActualGain+1.00   	PredLongTermGain+0.91
# 231 	CurrClose:724.25   	PredCurrGain+748.9796143   	ActualGain+0.99   	PredLongTermGain+0.87
# 232 	CurrClose:704.25   	PredCurrGain+743.2371216   	ActualGain+0.97   	PredLongTermGain+0.79
# 233 	CurrClose:706.13   	PredCurrGain+731.4783936   	ActualGain+1.00   	PredLongTermGain+0.80
# 234 	CurrClose:708.88   	PredCurrGain+725.7235107   	ActualGain+1.00   	PredLongTermGain+0.81
# 235 	CurrClose:710.47   	PredCurrGain+724.2847900   	ActualGain+1.00   	PredLongTermGain+0.81
# 236 	CurrClose:714.87   	PredCurrGain+725.2104492   	ActualGain+1.01   	PredLongTermGain+0.83
# 237 	CurrClose:685.20   	PredCurrGain+725.6416626   	ActualGain+0.96   	PredLongTermGain+0.71
# 238 	CurrClose:681.14   	PredCurrGain+712.8422241   	ActualGain+0.99   	PredLongTermGain+0.70
# 239 	CurrClose:691.26   	PredCurrGain+700.4735718   	ActualGain+1.01   	PredLongTermGain+0.73
# 240 	CurrClose:695.19   	PredCurrGain+701.4330444   	ActualGain+1.01   	PredLongTermGain+0.75
# 241 	CurrClose:703.53   	PredCurrGain+706.2423706   	ActualGain+1.01   	PredLongTermGain+0.78
# 242 	CurrClose:710.25   	PredCurrGain+712.2550659   	ActualGain+1.01   	PredLongTermGain+0.80
# 243 	CurrClose:704.89   	PredCurrGain+720.2114258   	ActualGain+0.99   	PredLongTermGain+0.78
# 244 	CurrClose:708.97   	PredCurrGain+721.2659302   	ActualGain+1.01   	PredLongTermGain+0.80
# 245 	CurrClose:707.26   	PredCurrGain+721.8023682   	ActualGain+1.00   	PredLongTermGain+0.79
# 246 	CurrClose:717.78   	PredCurrGain+722.4310913   	ActualGain+1.01   	PredLongTermGain+0.83
# 247 	CurrClose:727.20   	PredCurrGain+726.7633057   	ActualGain+1.01   	PredLongTermGain+0.87
# 248 	CurrClose:732.51   	PredCurrGain+735.0317993   	ActualGain+1.01   	PredLongTermGain+0.89
# 249 	CurrClose:729.48   	PredCurrGain+743.7780762   	ActualGain+1.00   	PredLongTermGain+0.88
# 250 	CurrClose:735.80   	PredCurrGain+747.5428467   	ActualGain+1.01   	PredLongTermGain+0.91
# 251 	CurrClose:735.63   	PredCurrGain+749.9823608   	ActualGain+1.00   	PredLongTermGain+0.91
# 252 	CurrClose:753.20   	PredCurrGain+752.4605713   	ActualGain+1.02   	PredLongTermGain+0.98
# 253 	CurrClose:753.41   	PredCurrGain+758.7549438   	ActualGain+1.00   	PredLongTermGain+0.98
# 254 	CurrClose:757.08   	PredCurrGain+765.4041138   	ActualGain+1.00   	PredLongTermGain+1.00
# 255 	CurrClose:754.41   	PredCurrGain+770.9644165   	ActualGain+1.00   	PredLongTermGain+0.99
# 256 	CurrClose:759.28   	PredCurrGain+772.1190796   	ActualGain+1.01   	PredLongTermGain+1.01
# 257 	CurrClose:757.52   	PredCurrGain+773.4403076   	ActualGain+1.00   	PredLongTermGain+1.00
# 258 	CurrClose:757.65   	PredCurrGain+773.6677856   	ActualGain+1.00   	PredLongTermGain+1.00
# 259 	CurrClose:761.97   	PredCurrGain+773.2503052   	ActualGain+1.01   	PredLongTermGain+1.02
# 260 	CurrClose:765.84   	PredCurrGain+775.2025146   	ActualGain+1.01   	PredLongTermGain+1.04
# 261 	CurrClose:791.34   	PredCurrGain+778.8778687   	ActualGain+1.03   	PredLongTermGain+1.16
# 262 	CurrClose:800.94   	PredCurrGain+799.3110352   	ActualGain+1.01   	PredLongTermGain+1.21
# 263 	CurrClose:800.12   	PredCurrGain+810.3085938   	ActualGain+1.00   	PredLongTermGain+1.21
# 264 	CurrClose:798.92   	PredCurrGain+816.6360474   	ActualGain+1.00   	PredLongTermGain+1.20
# 265 	CurrClose:797.25   	PredCurrGain+817.3224487   	ActualGain+1.00   	PredLongTermGain+1.19
# 266 	CurrClose:806.93   	PredCurrGain+816.6712646   	ActualGain+1.01   	PredLongTermGain+1.24
# 267 	CurrClose:805.23   	PredCurrGain+819.4788818   	ActualGain+1.00   	PredLongTermGain+1.23
# 268 	CurrClose:807.48   	PredCurrGain+821.9526978   	ActualGain+1.00   	PredLongTermGain+1.24
# 269 	CurrClose:808.49   	PredCurrGain+824.3015747   	ActualGain+1.00   	PredLongTermGain+1.25
# 270 	CurrClose:808.20   	PredCurrGain+826.1593018   	ActualGain+1.00   	PredLongTermGain+1.25
# 271 	CurrClose:807.05   	PredCurrGain+827.4153442   	ActualGain+1.00   	PredLongTermGain+1.24
# 272 	CurrClose:805.96   	PredCurrGain+825.8390503   	ActualGain+1.00   	PredLongTermGain+1.24
# 273 	CurrClose:801.19   	PredCurrGain+825.5709839   	ActualGain+0.99   	PredLongTermGain+1.21
# 274 	CurrClose:805.42   	PredCurrGain+821.9332275   	ActualGain+1.01   	PredLongTermGain+1.23
# 275 	CurrClose:802.75   	PredCurrGain+820.8580933   	ActualGain+1.00   	PredLongTermGain+1.22
# 276 	CurrClose:799.65   	PredCurrGain+822.0426636   	ActualGain+1.00   	PredLongTermGain+1.20
# 277 	CurrClose:796.95   	PredCurrGain+819.7526855   	ActualGain+1.00   	PredLongTermGain+1.19
# 278 	CurrClose:796.59   	PredCurrGain+817.3641357   	ActualGain+1.00   	PredLongTermGain+1.19
# 279 	CurrClose:793.60   	PredCurrGain+817.0542603   	ActualGain+1.00   	PredLongTermGain+1.17
# 280 	CurrClose:791.30   	PredCurrGain+814.7903442   	ActualGain+1.00   	PredLongTermGain+1.16
# 281 	CurrClose:793.22   	PredCurrGain+811.7456665   	ActualGain+1.00   	PredLongTermGain+1.17
# 282 	CurrClose:795.82   	PredCurrGain+811.9666138   	ActualGain+1.00   	PredLongTermGain+1.18
# 283 	CurrClose:791.92   	PredCurrGain+813.2412109   	ActualGain+1.00   	PredLongTermGain+1.16
# 284 	CurrClose:789.85   	PredCurrGain+812.7655640   	ActualGain+1.00   	PredLongTermGain+1.15
# 285 	CurrClose:791.40   	PredCurrGain+810.4585571   	ActualGain+1.00   	PredLongTermGain+1.16
# 286 	CurrClose:796.87   	PredCurrGain+809.8719482   	ActualGain+1.01   	PredLongTermGain+1.19
# 287 	CurrClose:808.02   	PredCurrGain+813.0106201   	ActualGain+1.01   	PredLongTermGain+1.24
# 288 	CurrClose:807.99   	PredCurrGain+819.4631348   	ActualGain+1.00   	PredLongTermGain+1.24
# 289 	CurrClose:802.84   	PredCurrGain+825.3073120   	ActualGain+0.99   	PredLongTermGain+1.22
# 290 	CurrClose:788.48   	PredCurrGain+825.3528442   	ActualGain+0.98   	PredLongTermGain+1.14
# 291 	CurrClose:798.82   	PredCurrGain+817.5624390   	ActualGain+1.01   	PredLongTermGain+1.19
# 292 	CurrClose:788.72   	PredCurrGain+813.1190186   	ActualGain+0.99   	PredLongTermGain+1.14
# 293 	CurrClose:790.46   	PredCurrGain+809.8609619   	ActualGain+1.00   	PredLongTermGain+1.15
# 294 	CurrClose:801.23   	PredCurrGain+809.0487671   	ActualGain+1.01   	PredLongTermGain+1.20
# 295 	CurrClose:797.97   	PredCurrGain+812.8248291   	ActualGain+1.00   	PredLongTermGain+1.19
# 296 	CurrClose:795.39   	PredCurrGain+815.3869019   	ActualGain+1.00   	PredLongTermGain+1.17
# 297 	CurrClose:799.78   	PredCurrGain+817.1123047   	ActualGain+1.01   	PredLongTermGain+1.20
# 298 	CurrClose:805.03   	PredCurrGain+819.1980591   	ActualGain+1.01   	PredLongTermGain+1.22
# 299 	CurrClose:815.95   	PredCurrGain+821.1809082   	ActualGain+1.01   	PredLongTermGain+1.28
# 300 	CurrClose:814.96   	PredCurrGain+828.9492798   	ActualGain+1.00   	PredLongTermGain+1.28
# 301 	CurrClose:802.65   	PredCurrGain+833.5739136   	ActualGain+0.98   	PredLongTermGain+1.21
# 302 	CurrClose:810.73   	PredCurrGain+828.7675171   	ActualGain+1.01   	PredLongTermGain+1.25
# 303 	CurrClose:810.06   	PredCurrGain+827.3732300   	ActualGain+1.00   	PredLongTermGain+1.25
# 304 	CurrClose:802.64   	PredCurrGain+826.5588989   	ActualGain+0.99   	PredLongTermGain+1.21
# 305 	CurrClose:804.06   	PredCurrGain+825.2197266   	ActualGain+1.00   	PredLongTermGain+1.22
# 306 	CurrClose:800.38   	PredCurrGain+823.8834229   	ActualGain+1.00   	PredLongTermGain+1.20
# 307 	CurrClose:802.79   	PredCurrGain+821.0323486   	ActualGain+1.00   	PredLongTermGain+1.21
# 308 	CurrClose:801.23   	PredCurrGain+821.6838989   	ActualGain+1.00   	PredLongTermGain+1.20
# 309 	CurrClose:803.08   	PredCurrGain+822.5302124   	ActualGain+1.00   	PredLongTermGain+1.21
# 310 	CurrClose:800.71   	PredCurrGain+823.0375977   	ActualGain+1.00   	PredLongTermGain+1.20
# 311 	CurrClose:814.17   	PredCurrGain+822.2178345   	ActualGain+1.02   	PredLongTermGain+1.27
# 312 	CurrClose:809.57   	PredCurrGain+826.8491821   	ActualGain+0.99   	PredLongTermGain+1.24
# 313 	CurrClose:811.77   	PredCurrGain+830.5938110   	ActualGain+1.00   	PredLongTermGain+1.25
# 314 	CurrClose:804.08   	PredCurrGain+832.0820312   	ActualGain+0.99   	PredLongTermGain+1.21
# 315 	CurrClose:804.60   	PredCurrGain+827.0416260   	ActualGain+1.00   	PredLongTermGain+1.22
# 316 	CurrClose:806.84   	PredCurrGain+825.7349243   	ActualGain+1.00   	PredLongTermGain+1.23
# 317 	CurrClose:821.49   	PredCurrGain+826.3316040   	ActualGain+1.02   	PredLongTermGain+1.31
# 318 	CurrClose:826.84   	PredCurrGain+834.3513184   	ActualGain+1.01   	PredLongTermGain+1.34
# 319 	CurrClose:821.63   	PredCurrGain+842.6406860   	ActualGain+0.99   	PredLongTermGain+1.31
# 320 	CurrClose:824.06   	PredCurrGain+844.9710083   	ActualGain+1.00   	PredLongTermGain+1.32
# 321 	CurrClose:835.74   	PredCurrGain+843.8829346   	ActualGain+1.01   	PredLongTermGain+1.38
# 322 	CurrClose:828.55   	PredCurrGain+850.3004150   	ActualGain+0.99   	PredLongTermGain+1.34
# 323 	CurrClose:822.10   	PredCurrGain+851.9906006   	ActualGain+0.99   	PredLongTermGain+1.31
# 324 	CurrClose:817.35   	PredCurrGain+846.6597290   	ActualGain+0.99   	PredLongTermGain+1.28
# 325 	CurrClose:819.56   	PredCurrGain+841.4494629   	ActualGain+1.00   	PredLongTermGain+1.29
# 326 	CurrClose:809.90   	PredCurrGain+842.3067017   	ActualGain+0.99   	PredLongTermGain+1.24
# 327 	CurrClose:805.48   	PredCurrGain+837.3699951   	ActualGain+0.99   	PredLongTermGain+1.22
# 328 	CurrClose:788.42   	PredCurrGain+829.8964844   	ActualGain+0.98   	PredLongTermGain+1.13
# 329 	CurrClose:782.19   	PredCurrGain+819.3294067   	ActualGain+0.99   	PredLongTermGain+1.09
# 330 	CurrClose:781.10   	PredCurrGain+807.6567383   	ActualGain+1.00   	PredLongTermGain+1.09
# 331 	CurrClose:802.03   	PredCurrGain+799.6548462   	ActualGain+1.03   	PredLongTermGain+1.19
# 332 	CurrClose:811.98   	PredCurrGain+810.2512817   	ActualGain+1.01   	PredLongTermGain+1.24
# 333 	CurrClose:805.59   	PredCurrGain+822.1602783   	ActualGain+0.99   	PredLongTermGain+1.21
# 334 	CurrClose:780.29   	PredCurrGain+824.0669556   	ActualGain+0.97   	PredLongTermGain+1.08
# 335 	CurrClose:771.75   	PredCurrGain+814.6392212   	ActualGain+0.99   	PredLongTermGain+1.03
# 336 	CurrClose:753.22   	PredCurrGain+799.8389893   	ActualGain+0.98   	PredLongTermGain+0.95
# 337 	CurrClose:775.16   	PredCurrGain+783.6454468   	ActualGain+1.03   	PredLongTermGain+1.04
# 338 	CurrClose:779.98   	PredCurrGain+785.7108765   	ActualGain+1.01   	PredLongTermGain+1.07
# 339 	CurrClose:786.16   	PredCurrGain+790.7176514   	ActualGain+1.01   	PredLongTermGain+1.10
# 340 	CurrClose:775.97   	PredCurrGain+799.4561768   	ActualGain+0.99   	PredLongTermGain+1.05
# 341 	CurrClose:784.80   	PredCurrGain+801.4027710   	ActualGain+1.01   	PredLongTermGain+1.09
# 342 	CurrClose:785.00   	PredCurrGain+802.1237793   	ActualGain+1.00   	PredLongTermGain+1.09
# 343 	CurrClose:779.00   	PredCurrGain+805.5217896   	ActualGain+0.99   	PredLongTermGain+1.06
# 344 	CurrClose:780.23   	PredCurrGain+803.1819458   	ActualGain+1.00   	PredLongTermGain+1.07
# 345 	CurrClose:785.79   	PredCurrGain+801.2866211   	ActualGain+1.01   	PredLongTermGain+1.09
# 346 	CurrClose:789.44   	PredCurrGain+802.5332031   	ActualGain+1.00   	PredLongTermGain+1.11
# 347 	CurrClose:775.88   	PredCurrGain+806.5148315   	ActualGain+0.98   	PredLongTermGain+1.04
# 348 	CurrClose:764.33   	PredCurrGain+802.6002197   	ActualGain+0.99   	PredLongTermGain+0.99
# 349 	CurrClose:764.46   	PredCurrGain+791.5737305   	ActualGain+1.00   	PredLongTermGain+0.99
# 350 	CurrClose:778.22   	PredCurrGain+784.5857544   	ActualGain+1.02   	PredLongTermGain+1.05
# 351 	CurrClose:776.18   	PredCurrGain+788.3405151   	ActualGain+1.00   	PredLongTermGain+1.04
# 352 	CurrClose:791.47   	PredCurrGain+793.4920044   	ActualGain+1.02   	PredLongTermGain+1.11
# 353 	CurrClose:795.17   	PredCurrGain+800.3175049   	ActualGain+1.00   	PredLongTermGain+1.13
# 354 	CurrClose:809.45   	PredCurrGain+809.2552490   	ActualGain+1.02   	PredLongTermGain+1.20
# 355 	CurrClose:807.90   	PredCurrGain+819.9145508   	ActualGain+1.00   	PredLongTermGain+1.20
# 356 	CurrClose:815.34   	PredCurrGain+825.8579102   	ActualGain+1.01   	PredLongTermGain+1.23
# 357 	CurrClose:817.89   	PredCurrGain+832.9162598   	ActualGain+1.00   	PredLongTermGain+1.25
# 358 	CurrClose:815.65   	PredCurrGain+836.6859741   	ActualGain+1.00   	PredLongTermGain+1.24
# 359 	CurrClose:809.84   	PredCurrGain+836.9884033   	ActualGain+0.99   	PredLongTermGain+1.20
# 360 	CurrClose:812.50   	PredCurrGain+833.9147949   	ActualGain+1.00   	PredLongTermGain+1.22
# 361 	CurrClose:815.20   	PredCurrGain+831.0760498   	ActualGain+1.00   	PredLongTermGain+1.23
# 362 	CurrClose:812.20   	PredCurrGain+831.9630737   	ActualGain+1.00   	PredLongTermGain+1.22
# 363 	CurrClose:809.68   	PredCurrGain+831.0968018   	ActualGain+1.00   	PredLongTermGain+1.20
# 364 	CurrClose:807.80   	PredCurrGain+829.0935669   	ActualGain+1.00   	PredLongTermGain+1.19
# 365 	CurrClose:809.93   	PredCurrGain+827.6411743   	ActualGain+1.00   	PredLongTermGain+1.21
# 366 	CurrClose:804.57   	PredCurrGain+828.4457397   	ActualGain+0.99   	PredLongTermGain+1.18
# 367 	CurrClose:802.88   	PredCurrGain+827.5642090   	ActualGain+1.00   	PredLongTermGain+1.17
# 368 	CurrClose:792.45   	PredCurrGain+823.8784790   	ActualGain+0.99   	PredLongTermGain+1.12
# 369 	CurrClose:808.01   	PredCurrGain+818.0822144   	ActualGain+1.02   	PredLongTermGain+1.19
# 370 	CurrClose:807.77   	PredCurrGain+821.0039673   	ActualGain+1.00   	PredLongTermGain+1.19
# 371 	CurrClose:813.02   	PredCurrGain+825.7059937   	ActualGain+1.01   	PredLongTermGain+1.22
# 372 	CurrClose:825.21   	PredCurrGain+829.2488403   	ActualGain+1.01   	PredLongTermGain+1.28
# 373 	CurrClose:827.18   	PredCurrGain+837.0145874   	ActualGain+1.00   	PredLongTermGain+1.29
# 374 	CurrClose:826.01   	PredCurrGain+844.3897705   	ActualGain+1.00   	PredLongTermGain+1.29
# 375 	CurrClose:829.86   	PredCurrGain+847.1743774   	ActualGain+1.00   	PredLongTermGain+1.31
# 376 	CurrClose:829.53   	PredCurrGain+848.1602783   	ActualGain+1.00   	PredLongTermGain+1.31
# 377 	CurrClose:830.94   	PredCurrGain+848.1466064   	ActualGain+1.00   	PredLongTermGain+1.31
# 378 	CurrClose:827.46   	PredCurrGain+850.4482422   	ActualGain+1.00   	PredLongTermGain+1.29
# 379 	CurrClose:829.02   	PredCurrGain+848.8060303   	ActualGain+1.00   	PredLongTermGain+1.30
# 380 	CurrClose:824.37   	PredCurrGain+848.3826294   	ActualGain+0.99   	PredLongTermGain+1.28
# 381 	CurrClose:828.17   	PredCurrGain+847.4990845   	ActualGain+1.00   	PredLongTermGain+1.30
# 382 	CurrClose:844.43   	PredCurrGain+847.5961304   	ActualGain+1.02   	PredLongTermGain+1.39
# 383 	CurrClose:849.53   	PredCurrGain+854.1921387   	ActualGain+1.01   	PredLongTermGain+1.42
# 384 	CurrClose:858.45   	PredCurrGain+863.9541016   	ActualGain+1.01   	PredLongTermGain+1.47
# 385 	CurrClose:856.98   	PredCurrGain+873.2388306   	ActualGain+1.00   	PredLongTermGain+1.46
# 386 	CurrClose:845.03   	PredCurrGain+877.0371704   	ActualGain+0.99   	PredLongTermGain+1.39
# 387 	CurrClose:823.83   	PredCurrGain+874.6452026   	ActualGain+0.97   	PredLongTermGain+1.27
# 388 	CurrClose:820.19   	PredCurrGain+858.2555542   	ActualGain+1.00   	PredLongTermGain+1.25
# 389 	CurrClose:815.24   	PredCurrGain+844.6391602   	ActualGain+0.99   	PredLongTermGain+1.22
# 390 	CurrClose:818.26   	PredCurrGain+838.3070679   	ActualGain+1.00   	PredLongTermGain+1.24
# 391 	CurrClose:820.13   	PredCurrGain+836.4465332   	ActualGain+1.00   	PredLongTermGain+1.25
# 392 	CurrClose:821.62   	PredCurrGain+839.5528564   	ActualGain+1.00   	PredLongTermGain+1.25
# 393 	CurrClose:829.23   	PredCurrGain+840.4161987   	ActualGain+1.01   	PredLongTermGain+1.29
# 394 	CurrClose:829.88   	PredCurrGain+845.8182373   	ActualGain+1.00   	PredLongTermGain+1.30
# 395 	CurrClose:830.06   	PredCurrGain+849.8875732   	ActualGain+1.00   	PredLongTermGain+1.30
# 396 	CurrClose:834.85   	PredCurrGain+851.5515137   	ActualGain+1.01   	PredLongTermGain+1.33
# 397 	CurrClose:838.96   	PredCurrGain+854.3012085   	ActualGain+1.00   	PredLongTermGain+1.35
# 398 	CurrClose:840.03   	PredCurrGain+858.3556519   	ActualGain+1.00   	PredLongTermGain+1.35
# 399 	CurrClose:837.32   	PredCurrGain+860.3292236   	ActualGain+1.00   	PredLongTermGain+1.34
# 400 	CurrClose:842.17   	PredCurrGain+860.1320190   	ActualGain+1.01   	PredLongTermGain+1.37
# 401 	CurrClose:846.55   	PredCurrGain+861.1372070   	ActualGain+1.01   	PredLongTermGain+1.39
# 402 	CurrClose:849.27   	PredCurrGain+863.6040039   	ActualGain+1.00   	PredLongTermGain+1.41
# 403 	CurrClose:851.36   	PredCurrGain+868.0295410   	ActualGain+1.00   	PredLongTermGain+1.42
# 404 	CurrClose:851.00   	PredCurrGain+870.6604004   	ActualGain+1.00   	PredLongTermGain+1.42
# 405 	CurrClose:847.81   	PredCurrGain+870.9473267   	ActualGain+1.00   	PredLongTermGain+1.40
# 406 	CurrClose:849.67   	PredCurrGain+869.1625977   	ActualGain+1.00   	PredLongTermGain+1.41
# 407 	CurrClose:844.93   	PredCurrGain+868.6365967   	ActualGain+0.99   	PredLongTermGain+1.38
# 408 	CurrClose:856.75   	PredCurrGain+867.0629272   	ActualGain+1.01   	PredLongTermGain+1.45
# 409 	CurrClose:849.85   	PredCurrGain+871.9333496   	ActualGain+0.99   	PredLongTermGain+1.41
# 410 	CurrClose:849.08   	PredCurrGain+873.5120850   	ActualGain+1.00   	PredLongTermGain+1.40
# 411 	CurrClose:847.27   	PredCurrGain+871.6004639   	ActualGain+1.00   	PredLongTermGain+1.39
# 412 	CurrClose:851.15   	PredCurrGain+868.9533081   	ActualGain+1.00   	PredLongTermGain+1.42
# 413 	CurrClose:853.64   	PredCurrGain+869.9726562   	ActualGain+1.00   	PredLongTermGain+1.43
# 414 	CurrClose:857.84   	PredCurrGain+873.4117432   	ActualGain+1.00   	PredLongTermGain+1.45
# 415 	CurrClose:861.41   	PredCurrGain+876.7419434   	ActualGain+1.00   	PredLongTermGain+1.48
# 416 	CurrClose:864.58   	PredCurrGain+881.4061279   	ActualGain+1.00   	PredLongTermGain+1.49
# 417 	CurrClose:865.91   	PredCurrGain+884.7864990   	ActualGain+1.00   	PredLongTermGain+1.50
# 418 	CurrClose:868.39   	PredCurrGain+886.5805054   	ActualGain+1.00   	PredLongTermGain+1.52
# 419 	CurrClose:870.00   	PredCurrGain+888.4854126   	ActualGain+1.00   	PredLongTermGain+1.53
# 420 	CurrClose:872.37   	PredCurrGain+891.2964478   	ActualGain+1.00   	PredLongTermGain+1.54
# 421 	CurrClose:867.91   	PredCurrGain+893.3966675   	ActualGain+0.99   	PredLongTermGain+1.51
# 422 	CurrClose:850.14   	PredCurrGain+891.5629272   	ActualGain+0.98   	PredLongTermGain+1.41
# 423 	CurrClose:849.80   	PredCurrGain+883.8592529   	ActualGain+1.00   	PredLongTermGain+1.40
# 424 	CurrClose:839.65   	PredCurrGain+875.7810059   	ActualGain+0.99   	PredLongTermGain+1.35
# 425 	CurrClose:835.14   	PredCurrGain+864.2938843   	ActualGain+0.99   	PredLongTermGain+1.32
# 426 	CurrClose:838.51   	PredCurrGain+858.8038940   	ActualGain+1.00   	PredLongTermGain+1.34
# 427 	CurrClose:840.63   	PredCurrGain+855.2681885   	ActualGain+1.00   	PredLongTermGain+1.35
# 428 	CurrClose:849.87   	PredCurrGain+858.3986816   	ActualGain+1.01   	PredLongTermGain+1.40
# 429 	CurrClose:849.48   	PredCurrGain+865.2979736   	ActualGain+1.00   	PredLongTermGain+1.40
# 430 	CurrClose:847.80   	PredCurrGain+870.7976074   	ActualGain+1.00   	PredLongTermGain+1.39
# 431 	CurrClose:856.75   	PredCurrGain+871.0930786   	ActualGain+1.01   	PredLongTermGain+1.44
# 432 	CurrClose:852.57   	PredCurrGain+874.2946167   	ActualGain+1.00   	PredLongTermGain+1.42
# 433 	CurrClose:848.91   	PredCurrGain+873.8695679   	ActualGain+1.00   	PredLongTermGain+1.40
# 434 	CurrClose:845.10   	PredCurrGain+874.0724487   	ActualGain+1.00   	PredLongTermGain+1.37
# 435 	CurrClose:842.10   	PredCurrGain+871.1945801   	ActualGain+1.00   	PredLongTermGain+1.36
# 436 	CurrClose:841.70   	PredCurrGain+866.4783936   	ActualGain+1.00   	PredLongTermGain+1.35
# 437 	CurrClose:839.88   	PredCurrGain+864.5308838   	ActualGain+1.00   	PredLongTermGain+1.34
# 438 	CurrClose:841.46   	PredCurrGain+862.2711182   	ActualGain+1.00   	PredLongTermGain+1.35
# 439 	CurrClose:840.18   	PredCurrGain+861.7752075   	ActualGain+1.00   	PredLongTermGain+1.35
# 440 	CurrClose:855.13   	PredCurrGain+861.9130859   	ActualGain+1.02   	PredLongTermGain+1.43
# 441 	CurrClose:853.99   	PredCurrGain+867.6303711   	ActualGain+1.00   	PredLongTermGain+1.42
# 442 	CurrClose:856.51   	PredCurrGain+873.5973511   	ActualGain+1.00   	PredLongTermGain+1.44
# 443 	CurrClose:860.08   	PredCurrGain+877.9063110   	ActualGain+1.00   	PredLongTermGain+1.46
# 444 	CurrClose:858.95   	PredCurrGain+881.6118774   	ActualGain+1.00   	PredLongTermGain+1.45
# 445 	CurrClose:878.93   	PredCurrGain+882.5120239   	ActualGain+1.02   	PredLongTermGain+1.57
# 446 	CurrClose:888.84   	PredCurrGain+891.4472656   	ActualGain+1.01   	PredLongTermGain+1.63
# 447 	CurrClose:889.14   	PredCurrGain+903.2041016   	ActualGain+1.00   	PredLongTermGain+1.63
# 448 	CurrClose:891.44   	PredCurrGain+910.6251221   	ActualGain+1.00   	PredLongTermGain+1.65
# 449 	CurrClose:924.52   	PredCurrGain+913.3486328   	ActualGain+1.04   	PredLongTermGain+1.86
# 450 	CurrClose:932.82   	PredCurrGain+937.5396729   	ActualGain+1.01   	PredLongTermGain+1.92
# 451 	CurrClose:937.09   	PredCurrGain+949.7238159   	ActualGain+1.00   	PredLongTermGain+1.95
# 452 	CurrClose:948.45   	PredCurrGain+958.5876465   	ActualGain+1.01   	PredLongTermGain+2.04
# 453 	CurrClose:954.72   	PredCurrGain+965.6188354   	ActualGain+1.01   	PredLongTermGain+2.08
# 454 	CurrClose:950.28   	PredCurrGain+974.0740356   	ActualGain+1.00   	PredLongTermGain+2.05
# 455 	CurrClose:958.69   	PredCurrGain+976.9182129   	ActualGain+1.01   	PredLongTermGain+2.11
# 456 	CurrClose:956.71   	PredCurrGain+978.1691284   	ActualGain+1.00   	PredLongTermGain+2.10
# 457 	CurrClose:954.84   	PredCurrGain+981.0656128   	ActualGain+1.00   	PredLongTermGain+2.08
# 458 	CurrClose:955.89   	PredCurrGain+979.7367554   	ActualGain+1.00   	PredLongTermGain+2.09
# 459 	CurrClose:955.14   	PredCurrGain+978.5573730   	ActualGain+1.00   	PredLongTermGain+2.08
# 460 	CurrClose:959.22   	PredCurrGain+979.3498535   	ActualGain+1.00   	PredLongTermGain+2.12
# 461 	CurrClose:964.61   	PredCurrGain+981.2984009   	ActualGain+1.01   	PredLongTermGain+2.16
# 462 	CurrClose:942.17   	PredCurrGain+986.5188599   	ActualGain+0.98   	PredLongTermGain+1.98
# 463 	CurrClose:950.50   	PredCurrGain+978.6646729   	ActualGain+1.01   	PredLongTermGain+2.04
# 464 	CurrClose:954.65   	PredCurrGain+974.4951782   	ActualGain+1.00   	PredLongTermGain+2.07
# 465 	CurrClose:964.07   	PredCurrGain+977.9934692   	ActualGain+1.01   	PredLongTermGain+2.15
# 466 	CurrClose:970.55   	PredCurrGain+984.1809082   	ActualGain+1.01   	PredLongTermGain+2.20
# 467 	CurrClose:977.61   	PredCurrGain+992.7807617   	ActualGain+1.01   	PredLongTermGain+2.25
# 468 	CurrClose:991.86   	PredCurrGain+1000.5186157   	ActualGain+1.01   	PredLongTermGain+2.37
# 469 	CurrClose:993.27   	PredCurrGain+1010.2001953   	ActualGain+1.00   	PredLongTermGain+2.38
# 470 	CurrClose:996.17   	PredCurrGain+1017.7392578   	ActualGain+1.00   	PredLongTermGain+2.40
# 471 	CurrClose:987.09   	PredCurrGain+1021.7117920   	ActualGain+0.99   	PredLongTermGain+2.33
# 472 	CurrClose:988.29   	PredCurrGain+1019.4840698   	ActualGain+1.00   	PredLongTermGain+2.34
# 473 	CurrClose:996.12   	PredCurrGain+1016.8276978   	ActualGain+1.01   	PredLongTermGain+2.40
# 474 	CurrClose:1003.88   	PredCurrGain+1018.3200684   	ActualGain+1.01   	PredLongTermGain+2.47
# 475 	CurrClose:996.68   	PredCurrGain+1025.2567139   	ActualGain+0.99   	PredLongTermGain+2.40
# 476 	CurrClose:1001.50   	PredCurrGain+1027.4415283   	ActualGain+1.00   	PredLongTermGain+2.45
# 477 	CurrClose:1004.28   	PredCurrGain+1028.2890625   	ActualGain+1.00   	PredLongTermGain+2.47
# 478 	CurrClose:970.12   	PredCurrGain+1029.9002686   	ActualGain+0.97   	PredLongTermGain+2.18
# 479 	CurrClose:961.81   	PredCurrGain+1014.6176147   	ActualGain+0.99   	PredLongTermGain+2.11
# 480 	CurrClose:970.50   	PredCurrGain+992.3126221   	ActualGain+1.01   	PredLongTermGain+2.18
# 481 	CurrClose:967.93   	PredCurrGain+993.7075195   	ActualGain+1.00   	PredLongTermGain+2.16
# 482 	CurrClose:960.18   	PredCurrGain+995.8381348   	ActualGain+0.99   	PredLongTermGain+2.10
# 483 	CurrClose:958.62   	PredCurrGain+985.8989258   	ActualGain+1.00   	PredLongTermGain+2.08
# 484 	CurrClose:975.22   	PredCurrGain+983.7783203   	ActualGain+1.02   	PredLongTermGain+2.21
# 485 	CurrClose:968.99   	PredCurrGain+995.1664429   	ActualGain+0.99   	PredLongTermGain+2.16
# 486 	CurrClose:978.59   	PredCurrGain+1000.1887817   	ActualGain+1.01   	PredLongTermGain+2.24
# 487 	CurrClose:976.62   	PredCurrGain+1003.5269775   	ActualGain+1.00   	PredLongTermGain+2.22
# 488 	CurrClose:986.09   	PredCurrGain+1005.5007935   	ActualGain+1.01   	PredLongTermGain+2.30
# 489 	CurrClose:972.09   	PredCurrGain+1008.5430908   	ActualGain+0.99   	PredLongTermGain+2.18
# 490 	CurrClose:948.09   	PredCurrGain+1008.5618286   	ActualGain+0.98   	PredLongTermGain+1.99
# 491 	CurrClose:961.01   	PredCurrGain+991.2458496   	ActualGain+1.01   	PredLongTermGain+2.09
# 492 	CurrClose:937.82   	PredCurrGain+982.4376221   	ActualGain+0.98   	PredLongTermGain+1.91
# 493 	CurrClose:929.68   	PredCurrGain+971.5195312   	ActualGain+0.99   	PredLongTermGain+1.85
# 494 	CurrClose:919.46   	PredCurrGain+964.3305664   	ActualGain+0.99   	PredLongTermGain+1.78
# 495 	CurrClose:932.26   	PredCurrGain+954.8387451   	ActualGain+1.01   	PredLongTermGain+1.87
# 496 	CurrClose:927.69   	PredCurrGain+953.9055786   	ActualGain+1.00   	PredLongTermGain+1.84
# 497 	CurrClose:940.81   	PredCurrGain+953.7508545   	ActualGain+1.01   	PredLongTermGain+1.93
# 498 	CurrClose:951.00   	PredCurrGain+960.7964478   	ActualGain+1.01   	PredLongTermGain+2.00
# 499 	CurrClose:953.53   	PredCurrGain+971.0996704   	ActualGain+1.00   	PredLongTermGain+2.02
# 500 	CurrClose:967.66   	PredCurrGain+977.6384888   	ActualGain+1.01   	PredLongTermGain+2.12
# 501 	CurrClose:968.85   	PredCurrGain+988.1206665   	ActualGain+1.00   	PredLongTermGain+2.13
# 502 	CurrClose:976.91   	PredCurrGain+996.1194458   	ActualGain+1.01   	PredLongTermGain+2.20
# 503 	CurrClose:975.96   	PredCurrGain+1001.7650757   	ActualGain+1.00   	PredLongTermGain+2.19
# 504 	CurrClose:986.95   	PredCurrGain+1003.9034424   	ActualGain+1.01   	PredLongTermGain+2.27
# 505 	CurrClose:992.77   	PredCurrGain+1007.5394287   	ActualGain+1.01   	PredLongTermGain+2.32
# 506 	CurrClose:992.19   	PredCurrGain+1015.4014282   	ActualGain+1.00   	PredLongTermGain+2.32
# 507 	CurrClose:993.84   	PredCurrGain+1019.1693726   	ActualGain+1.00   	PredLongTermGain+2.33
# 508 	CurrClose:998.31   	PredCurrGain+1018.9841309   	ActualGain+1.00   	PredLongTermGain+2.37
# 509 	CurrClose:969.03   	PredCurrGain+1021.6748047   	ActualGain+0.97   	PredLongTermGain+2.12
# 510 	CurrClose:965.31   	PredCurrGain+1003.7998047   	ActualGain+1.00   	PredLongTermGain+2.10
# 511 	CurrClose:952.51   	PredCurrGain+995.7841797   	ActualGain+0.99   	PredLongTermGain+2.00
# ...
# 1237 	CurrClose:1446.47   	PredCurrGain+1447.4168701   	ActualGain+1.02   	PredLongTermGain+2.81
# 1238 	CurrClose:1452.54   	PredCurrGain+1472.6497803   	ActualGain+1.00   	PredLongTermGain+2.85
# 1239 	CurrClose:1434.12   	PredCurrGain+1486.0252686   	ActualGain+0.99   	PredLongTermGain+2.72
# 1240 	CurrClose:1424.64   	PredCurrGain+1481.5413818   	ActualGain+0.99   	PredLongTermGain+2.66
# 1241 	CurrClose:1450.66   	PredCurrGain+1472.1972656   	ActualGain+1.02   	PredLongTermGain+2.83
# 1242 	CurrClose:1463.98   	PredCurrGain+1474.9531250   	ActualGain+1.01   	PredLongTermGain+2.92
# 1243 	CurrClose:1432.70   	PredCurrGain+1491.1716309   	ActualGain+0.98   	PredLongTermGain+2.70
# 1244 	CurrClose:1441.10   	PredCurrGain+1488.2215576   	ActualGain+1.01   	PredLongTermGain+2.76
# 1245 	CurrClose:1362.54   	PredCurrGain+1477.6436768   	ActualGain+0.95   	PredLongTermGain+2.23
# 1246 	CurrClose:1397.17   	PredCurrGain+1440.0419922   	ActualGain+1.03   	PredLongTermGain+2.43
# 1247 	CurrClose:1418.05   	PredCurrGain+1422.7304688   	ActualGain+1.01   	PredLongTermGain+2.56
# 1248 	CurrClose:1442.00   	PredCurrGain+1439.0798340   	ActualGain+1.02   	PredLongTermGain+2.71
# 1249 	CurrClose:1469.93   	PredCurrGain+1463.5379639   	ActualGain+1.02   	PredLongTermGain+2.89
# 1250 	CurrClose:1499.65   	PredCurrGain+1495.0555420   	ActualGain+1.02   	PredLongTermGain+3.09
# 1251 	CurrClose:1489.92   	PredCurrGain+1524.9832764   	ActualGain+0.99   	PredLongTermGain+3.02
# 1252 	CurrClose:1503.60   	PredCurrGain+1535.5311279   	ActualGain+1.01   	PredLongTermGain+3.12
# 1253 	CurrClose:1518.66   	PredCurrGain+1539.7236328   	ActualGain+1.01   	PredLongTermGain+3.23
# 1254 	CurrClose:1539.01   	PredCurrGain+1547.0548096   	ActualGain+1.01   	PredLongTermGain+3.38
# 1255 	CurrClose:1512.23   	PredCurrGain+1557.0279541   	ActualGain+0.98   	PredLongTermGain+3.18
# 1256 	CurrClose:1520.86   	PredCurrGain+1564.2731934   	ActualGain+1.01   	PredLongTermGain+3.24
# 1257 	CurrClose:1516.88   	PredCurrGain+1549.3110352   	ActualGain+1.00   	PredLongTermGain+3.21
# 1258 	CurrClose:1514.92   	PredCurrGain+1551.1234131   	ActualGain+1.00   	PredLongTermGain+3.20
# 1259 	CurrClose:1516.85   	PredCurrGain+1544.1937256   	ActualGain+1.00   	PredLongTermGain+3.21
# 1260 	CurrClose:1563.84   	PredCurrGain+1547.0574951   	ActualGain+1.03   	PredLongTermGain+3.56
# 1261 	CurrClose:1555.92   	PredCurrGain+1567.4552002   	ActualGain+0.99   	PredLongTermGain+3.50
# 1262 	CurrClose:1564.85   	PredCurrGain+1594.3138428   	ActualGain+1.01   	PredLongTermGain+3.57
# 1263 	CurrClose:1516.75   	PredCurrGain+1595.5200195   	ActualGain+0.97   	PredLongTermGain+3.18
# 1264 	CurrClose:1508.21   	PredCurrGain+1577.5504150   	ActualGain+0.99   	PredLongTermGain+3.12
# 1265 	CurrClose:1529.43   	PredCurrGain+1548.7226562   	ActualGain+1.01   	PredLongTermGain+3.27
# 1266 	CurrClose:1503.65   	PredCurrGain+1554.9129639   	ActualGain+0.98   	PredLongTermGain+3.08
# 1267 	CurrClose:1523.51   	PredCurrGain+1549.9195557   	ActualGain+1.01   	PredLongTermGain+3.22
# 1268 	CurrClose:1538.37   	PredCurrGain+1552.5686035   	ActualGain+1.01   	PredLongTermGain+3.33
# 1269 	CurrClose:1487.95   	PredCurrGain+1555.8522949   	ActualGain+0.97   	PredLongTermGain+2.95
# 1270 	CurrClose:1482.76   	PredCurrGain+1529.8547363   	ActualGain+1.00   	PredLongTermGain+2.91
# 1271 	CurrClose:1473.30   	PredCurrGain+1523.3076172   	ActualGain+0.99   	PredLongTermGain+2.85
# 1272 	CurrClose:1479.09   	PredCurrGain+1517.7725830   	ActualGain+1.00   	PredLongTermGain+2.89
# 1273 	CurrClose:1504.95   	PredCurrGain+1517.8991699   	ActualGain+1.02   	PredLongTermGain+3.06
# 1274 	CurrClose:1498.37   	PredCurrGain+1526.9318848   	ActualGain+1.00   	PredLongTermGain+3.02
# 1275 	CurrClose:1496.82   	PredCurrGain+1537.8692627   	ActualGain+1.00   	PredLongTermGain+3.01
# 1276 	CurrClose:1480.54   	PredCurrGain+1534.9072266   	ActualGain+0.99   	PredLongTermGain+2.89
# 1277 	CurrClose:1507.24   	PredCurrGain+1529.8522949   	ActualGain+1.02   	PredLongTermGain+3.07
# 1278 	CurrClose:1516.65   	PredCurrGain+1535.4136963   	ActualGain+1.01   	PredLongTermGain+3.14
# 1279 	CurrClose:1504.63   	PredCurrGain+1550.5247803   	ActualGain+0.99   	PredLongTermGain+3.06
# 1280 	CurrClose:1516.24   	PredCurrGain+1548.7546387   	ActualGain+1.01   	PredLongTermGain+3.14
# 1281 	CurrClose:1555.78   	PredCurrGain+1551.9671631   	ActualGain+1.03   	PredLongTermGain+3.42
# 1282 	CurrClose:1544.61   	PredCurrGain+1571.5218506   	ActualGain+0.99   	PredLongTermGain+3.34
# 1283 	CurrClose:1576.25   	PredCurrGain+1583.6818848   	ActualGain+1.02   	PredLongTermGain+3.58
# 1284 	CurrClose:1575.57   	PredCurrGain+1593.2426758   	ActualGain+1.00   	PredLongTermGain+3.57
# 1285 	CurrClose:1585.15   	PredCurrGain+1606.1784668   	ActualGain+1.01   	PredLongTermGain+3.65
# 1286 	CurrClose:1605.85   	PredCurrGain+1619.7426758   	ActualGain+1.01   	PredLongTermGain+3.81
# 1287 	CurrClose:1644.13   	PredCurrGain+1627.0483398   	ActualGain+1.02   	PredLongTermGain+4.13
# 1288 	CurrClose:1628.52   	PredCurrGain+1651.0264893   	ActualGain+0.99   	PredLongTermGain+4.00
# 1289 	CurrClose:1639.43   	PredCurrGain+1663.1105957   	ActualGain+1.01   	PredLongTermGain+4.09
# 1290 	CurrClose:1629.53   	PredCurrGain+1666.0964355   	ActualGain+0.99   	PredLongTermGain+4.00
# 1291 	CurrClose:1655.08   	PredCurrGain+1665.5019531   	ActualGain+1.02   	PredLongTermGain+4.22
# 1292 	CurrClose:1717.39   	PredCurrGain+1672.6130371   	ActualGain+1.04   	PredLongTermGain+4.78
# 1293 	CurrClose:1629.51   	PredCurrGain+1709.7241211   	ActualGain+0.95   	PredLongTermGain+3.92
# 1294 	CurrClose:1581.21   	PredCurrGain+1689.7355957   	ActualGain+0.97   	PredLongTermGain+3.52
# 1295 	CurrClose:1523.60   	PredCurrGain+1636.3652344   	ActualGain+0.96   	PredLongTermGain+3.07
# 1296 	CurrClose:1547.23   	PredCurrGain+1580.3173828   	ActualGain+1.02   	PredLongTermGain+3.23
# 1297 	CurrClose:1526.05   	PredCurrGain+1576.7604980   	ActualGain+0.99   	PredLongTermGain+3.08
# 1298 	CurrClose:1515.76   	PredCurrGain+1575.8129883   	ActualGain+0.99   	PredLongTermGain+3.01
# 1299 	CurrClose:1508.83   	PredCurrGain+1561.6931152   	ActualGain+1.00   	PredLongTermGain+2.96
# 1300 	CurrClose:1535.12   	PredCurrGain+1561.2475586   	ActualGain+1.02   	PredLongTermGain+3.14
# 1301 	CurrClose:1512.09   	PredCurrGain+1571.2629395   	ActualGain+0.98   	PredLongTermGain+2.97
# 1302 	CurrClose:1487.04   	PredCurrGain+1569.4028320   	ActualGain+0.98   	PredLongTermGain+2.80
# 1303 	CurrClose:1451.09   	PredCurrGain+1536.5955811   	ActualGain+0.98   	PredLongTermGain+2.56
# 1304 	CurrClose:1430.14   	PredCurrGain+1510.2718506   	ActualGain+0.99   	PredLongTermGain+2.43
# 1305 	CurrClose:1459.82   	PredCurrGain+1477.7677002   	ActualGain+1.02   	PredLongTermGain+2.61
# 1306 	CurrClose:1409.39   	PredCurrGain+1487.3504639   	ActualGain+0.97   	PredLongTermGain+2.30
# 1307 	CurrClose:1422.86   	PredCurrGain+1474.0628662   	ActualGain+1.01   	PredLongTermGain+2.37
# 1308 	CurrClose:1439.06   	PredCurrGain+1464.2729492   	ActualGain+1.01   	PredLongTermGain+2.47
# 1309 	CurrClose:1458.66   	PredCurrGain+1470.7014160   	ActualGain+1.01   	PredLongTermGain+2.58
# 1310 	CurrClose:1466.02   	PredCurrGain+1495.4127197   	ActualGain+1.01   	PredLongTermGain+2.63
# 1311 	CurrClose:1465.60   	PredCurrGain+1505.3082275   	ActualGain+1.00   	PredLongTermGain+2.63
# 1312 	CurrClose:1487.90   	PredCurrGain+1508.4697266   	ActualGain+1.02   	PredLongTermGain+2.77
# 1313 	CurrClose:1455.60   	PredCurrGain+1522.2274170   	ActualGain+0.98   	PredLongTermGain+2.56
# 1314 	CurrClose:1482.83   	PredCurrGain+1507.0015869   	ActualGain+1.02   	PredLongTermGain+2.73
# 1315 	CurrClose:1451.02   	PredCurrGain+1511.0921631   	ActualGain+0.98   	PredLongTermGain+2.52
# 1316 	CurrClose:1459.14   	PredCurrGain+1503.7302246   	ActualGain+1.01   	PredLongTermGain+2.57
# 1317 	CurrClose:1483.43   	PredCurrGain+1496.1530762   	ActualGain+1.02   	PredLongTermGain+2.72
# 1318 	CurrClose:1510.45   	PredCurrGain+1509.8441162   	ActualGain+1.02   	PredLongTermGain+2.89
# 1319 	CurrClose:1564.59   	PredCurrGain+1532.3294678   	ActualGain+1.04   	PredLongTermGain+3.26
# 1320 	CurrClose:1567.07   	PredCurrGain+1576.9971924   	ActualGain+1.00   	PredLongTermGain+3.27
# 1321 	CurrClose:1563.44   	PredCurrGain+1602.2054443   	ActualGain+1.00   	PredLongTermGain+3.25
# 1322 	CurrClose:1555.47   	PredCurrGain+1603.5609131   	ActualGain+0.99   	PredLongTermGain+3.19
# 1323 	CurrClose:1567.70   	PredCurrGain+1592.9139404   	ActualGain+1.01   	PredLongTermGain+3.28
# 1324 	CurrClose:1529.95   	PredCurrGain+1597.5844727   	ActualGain+0.98   	PredLongTermGain+3.00
# 1325 	CurrClose:1551.08   	PredCurrGain+1586.5056152   	ActualGain+1.01   	PredLongTermGain+3.15
# 1326 	CurrClose:1585.99   	PredCurrGain+1579.0472412   	ActualGain+1.02   	PredLongTermGain+3.39
# 1327 	CurrClose:1606.66   	PredCurrGain+1606.7310791   	ActualGain+1.01   	PredLongTermGain+3.55
# 1328 	CurrClose:1632.98   	PredCurrGain+1626.1286621   	ActualGain+1.02   	PredLongTermGain+3.75
# 1329 	CurrClose:1584.29   	PredCurrGain+1650.6789551   	ActualGain+0.97   	PredLongTermGain+3.36
# 1330 	CurrClose:1598.88   	PredCurrGain+1635.7796631   	ActualGain+1.01   	PredLongTermGain+3.47
# 1331 	CurrClose:1510.80   	PredCurrGain+1627.7584229   	ActualGain+0.94   	PredLongTermGain+2.80
# 1332 	CurrClose:1556.88   	PredCurrGain+1578.0860596   	ActualGain+1.03   	PredLongTermGain+3.10
# 1333 	CurrClose:1616.11   	PredCurrGain+1576.2416992   	ActualGain+1.04   	PredLongTermGain+3.51
# 1334 	CurrClose:1624.32   	PredCurrGain+1642.6633301   	ActualGain+1.01   	PredLongTermGain+3.57
# 1335 	CurrClose:1645.66   	PredCurrGain+1662.3450928   	ActualGain+1.01   	PredLongTermGain+3.74
# 1336 	CurrClose:1745.85   	PredCurrGain+1671.4519043   	ActualGain+1.06   	PredLongTermGain+4.53
# 1337 	CurrClose:1762.50   	PredCurrGain+1738.8291016   	ActualGain+1.01   	PredLongTermGain+4.69
# 1338 	CurrClose:1759.73   	PredCurrGain+1782.4953613   	ActualGain+1.00   	PredLongTermGain+4.66
# 1339 	CurrClose:1761.42   	PredCurrGain+1783.6854248   	ActualGain+1.00   	PredLongTermGain+4.68
# 1340 	CurrClose:1737.72   	PredCurrGain+1796.7838135   	ActualGain+0.99   	PredLongTermGain+4.46
# 1341 	CurrClose:1747.23   	PredCurrGain+1769.0068359   	ActualGain+1.01   	PredLongTermGain+4.54
# 1342 	CurrClose:1742.82   	PredCurrGain+1770.5966797   	ActualGain+1.00   	PredLongTermGain+4.50
# 1343 	CurrClose:1772.26   	PredCurrGain+1769.3919678   	ActualGain+1.02   	PredLongTermGain+4.77
# 1344 	CurrClose:1774.03   	PredCurrGain+1778.5311279   	ActualGain+1.00   	PredLongTermGain+4.78
# 1345 	CurrClose:1761.66   	PredCurrGain+1791.6483154   	ActualGain+0.99   	PredLongTermGain+4.67
# 1346 	CurrClose:1740.64   	PredCurrGain+1789.7957764   	ActualGain+0.99   	PredLongTermGain+4.47
# 1347 	CurrClose:1758.57   	PredCurrGain+1776.1329346   	ActualGain+1.01   	PredLongTermGain+4.63
# 1348 	CurrClose:1736.38   	PredCurrGain+1771.7915039   	ActualGain+0.99   	PredLongTermGain+4.43
# 1349 	CurrClose:1727.56   	PredCurrGain+1771.2761230   	ActualGain+0.99   	PredLongTermGain+4.35
# 1350 	CurrClose:1763.90   	PredCurrGain+1758.9643555   	ActualGain+1.02   	PredLongTermGain+4.67
# 1351 	CurrClose:1764.13   	PredCurrGain+1767.9854736   	ActualGain+1.00   	PredLongTermGain+4.67
# 1352 	CurrClose:1787.02   	PredCurrGain+1783.0941162   	ActualGain+1.01   	PredLongTermGain+4.88
# 1353 	CurrClose:1754.40   	PredCurrGain+1799.2943115   	ActualGain+0.98   	PredLongTermGain+4.57
# 1354 	CurrClose:1795.36   	PredCurrGain+1790.3703613   	ActualGain+1.02   	PredLongTermGain+4.95
# 1355 	CurrClose:1824.97   	PredCurrGain+1804.7728271   	ActualGain+1.02   	PredLongTermGain+5.23
# 1356 	CurrClose:1821.84   	PredCurrGain+1826.7451172   	ActualGain+1.00   	PredLongTermGain+5.20
# 1357 	CurrClose:1823.76   	PredCurrGain+1842.4353027   	ActualGain+1.00   	PredLongTermGain+5.22
# 1358 	CurrClose:1817.03   	PredCurrGain+1843.0269775   	ActualGain+1.00   	PredLongTermGain+5.15
# 1359 	CurrClose:1811.33   	PredCurrGain+1837.3829346   	ActualGain+1.00   	PredLongTermGain+5.10
# 1360 	CurrClose:1777.86   	PredCurrGain+1828.9829102   	ActualGain+0.98   	PredLongTermGain+4.77
# 1361 	CurrClose:1767.65   	PredCurrGain+1814.8100586   	ActualGain+0.99   	PredLongTermGain+4.67
# 1362 	CurrClose:1774.80   	PredCurrGain+1790.0080566   	ActualGain+1.00   	PredLongTermGain+4.74
# 1363 	CurrClose:1752.26   	PredCurrGain+1789.7601318   	ActualGain+0.99   	PredLongTermGain+4.53
# 1364 	CurrClose:1761.08   	PredCurrGain+1787.5886230   	ActualGain+1.01   	PredLongTermGain+4.61
# 1365 	CurrClose:1757.19   	PredCurrGain+1783.6153564   	ActualGain+1.00   	PredLongTermGain+4.57
# 1366 	CurrClose:1740.51   	PredCurrGain+1784.9847412   	ActualGain+0.99   	PredLongTermGain+4.42
# 1367 	CurrClose:1726.22   	PredCurrGain+1776.7999268   	ActualGain+0.99   	PredLongTermGain+4.29
# 1368 	CurrClose:1734.56   	PredCurrGain+1761.3083496   	ActualGain+1.00   	PredLongTermGain+4.36
# 1369 	CurrClose:1720.22   	PredCurrGain+1751.2458496   	ActualGain+0.99   	PredLongTermGain+4.24
# 1370 	CurrClose:1728.23   	PredCurrGain+1750.3238525   	ActualGain+1.00   	PredLongTermGain+4.31
# 1371 	CurrClose:1734.16   	PredCurrGain+1756.1798096   	ActualGain+1.00   	PredLongTermGain+4.36
# 1372 	CurrClose:1773.96   	PredCurrGain+1760.9766846   	ActualGain+1.02   	PredLongTermGain+4.71
# 1373 	CurrClose:1757.76   	PredCurrGain+1782.9916992   	ActualGain+0.99   	PredLongTermGain+4.56
# 1374 	CurrClose:1736.25   	PredCurrGain+1793.9624023   	ActualGain+0.99   	PredLongTermGain+4.36
# 1375 	CurrClose:1752.64   	PredCurrGain+1779.3245850   	ActualGain+1.01   	PredLongTermGain+4.51
# 1376 	CurrClose:1726.13   	PredCurrGain+1774.7241211   	ActualGain+0.98   	PredLongTermGain+4.27
# 1377 	CurrClose:1740.05   	PredCurrGain+1764.8962402   	ActualGain+1.01   	PredLongTermGain+4.39
# 1378 	CurrClose:1722.88   	PredCurrGain+1761.5977783   	ActualGain+0.99   	PredLongTermGain+4.24
# 1379 	CurrClose:1774.34   	PredCurrGain+1748.1921387   	ActualGain+1.03   	PredLongTermGain+4.68
# 1380 	CurrClose:1797.83   	PredCurrGain+1771.9824219   	ActualGain+1.01   	PredLongTermGain+4.90
# 1381 	CurrClose:1756.29   	PredCurrGain+1801.9544678   	ActualGain+0.98   	PredLongTermGain+4.50
# 1382 	CurrClose:1737.43   	PredCurrGain+1795.0095215   	ActualGain+0.99   	PredLongTermGain+4.33
# 1383 	CurrClose:1747.25   	PredCurrGain+1773.4520264   	ActualGain+1.01   	PredLongTermGain+4.42
# 1384 	CurrClose:1730.92   	PredCurrGain+1767.9407959   	ActualGain+0.99   	PredLongTermGain+4.27
# 1385 	CurrClose:1727.62   	PredCurrGain+1767.2241211   	ActualGain+1.00   	PredLongTermGain+4.24
# 1386 	CurrClose:1784.47   	PredCurrGain+1758.4324951   	ActualGain+1.03   	PredLongTermGain+4.73
# 1387 	CurrClose:1880.07   	PredCurrGain+1784.1021729   	ActualGain+1.05   	PredLongTermGain+5.62
# 1388 	CurrClose:1884.15   	PredCurrGain+1857.0052490   	ActualGain+1.00   	PredLongTermGain+5.66
# 1389 	CurrClose:1892.56   	PredCurrGain+1902.6734619   	ActualGain+1.00   	PredLongTermGain+5.75
# 1390 	CurrClose:1894.28   	PredCurrGain+1908.9898682   	ActualGain+1.00   	PredLongTermGain+5.77
# 1391 	CurrClose:1907.95   	PredCurrGain+1908.5738525   	ActualGain+1.01   	PredLongTermGain+5.92
# 1392 	CurrClose:1818.94   	PredCurrGain+1910.0826416   	ActualGain+0.95   	PredLongTermGain+4.95
# 1393 	CurrClose:1853.20   	PredCurrGain+1864.1519775   	ActualGain+1.02   	PredLongTermGain+5.28
# 1394 	CurrClose:1827.36   	PredCurrGain+1863.7819824   	ActualGain+0.99   	PredLongTermGain+5.02
# 1395 	CurrClose:1893.07   	PredCurrGain+1848.8486328   	ActualGain+1.04   	PredLongTermGain+5.65
# 1396 	CurrClose:1919.12   	PredCurrGain+1881.1116943   	ActualGain+1.01   	PredLongTermGain+5.92
# 1397 	CurrClose:2058.88   	PredCurrGain+1922.2128906   	ActualGain+1.07   	PredLongTermGain+7.43
# 1398 	CurrClose:2053.63   	PredCurrGain+2028.9916992   	ActualGain+1.00   	PredLongTermGain+7.37
# 1399 	CurrClose:2088.83   	PredCurrGain+2052.7370605   	ActualGain+1.02   	PredLongTermGain+7.81
#
#
#
# Final gain comparasion:	 [7.80788694] rather than Long-Term-Gain [2.98566378] , Trading times 1399
# array([7.80788694])
